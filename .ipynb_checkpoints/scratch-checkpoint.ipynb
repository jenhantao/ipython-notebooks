# %%
### imports ###
from matplotlib import pyplot as plt
import sys
import os
import numpy as np
from scipy.signal import savgol_filter
pylab.rcParams['savefig.dpi'] = 150

# %%
### functions ###
def calcSlopes(positions, scores):
    slopes = []
    for i in range(1, len(positions)):
        slopes.append(float(scores[i] - scores[i-1])/float(positions[i] - positions[i-1]))
    return slopes

# %%
# create simulated peaks for testing
x1 = np.arange(-20,-10,0.01)
y1 = [0 for i in x1]
x2 = np.arange(-10, 0,0.01)
y2 = [-(-i-5)**2+25 for i in x2]
x3 = np.arange(0.,10,0.01)
y3 = [-0.5*(-i+3)*(-i+7) +12.5 for i in x3]
x4 = np.arange(10,20,0.01)
y4 = 5*np.random.random(len(x4))

x = np.concatenate((x1,x2,x3,x4))
y = np.concatenate((y1,y2,y3,y4))

# %%
# smooth data
order = 1
windowWidth = 9

smoothed_y = savgol_filter(y, window_length = windowWidth , polyorder = order)

# %%
plt.plot(x,y, linewidth=2)
plt.plot(x, smoothed_y, linestyle='--', color='red')
plt.legend(["data", "smoothed data"] )

# %%
plt.plot(x, smoothed_y-y)
