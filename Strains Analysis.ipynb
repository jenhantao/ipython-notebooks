# %% [markdown]
# # Strains Analysis

# %%
### header ###
__author__ = "Jenhan Tao"
__license__ = "BSD"
__email__ = "jenhantao@gmail.com"

### imports ###
import sys
import os
import pandas as pd
import numpy as np
import argparse
import matplotlib
import itertools
import scipy
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import linkage, dendrogram
import scipy
import pickle
from sklearn import preprocessing
import sklearn
from sklearn import decomposition
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
from sklearn import svm, datasets
from sklearn.utils import shuffle
from sklearn.metrics import roc_curve, auc
from sklearn import ensemble
from sklearn import neighbors
import networkx as nx
import matplotlib_venn
from sklearn.cross_validation import train_test_split
from random import shuffle

### notebook specific configuration ###
# %matplotlib inline
sys.path.append("/home/jenhan/code/seq_merge_pipe/")
matplotlib.pylab.rcParams['savefig.dpi'] = 200
sys.setrecursionlimit(3000)
os.chdir('/home/jenhan/analysis/strains_analysis/')
sns.set_context('notebook')
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Generate Score Files

# %%
# %%bash
# if [ ! -d ./group ]; then mkdir ./group; fi
# mergePeaks -d given -venn venn.txt ./peak_files/* > ./group/merged_peaks.tsv
# makeSummaryFile.py ./group/merged_peaks.tsv ./group_summary.tsv ./peak_files/*
# Out:
# Finished reading merged peak file...
# Integrating scores for balb_cebpa_kla
# Integrating scores for balb_cebpa_veh
# Integrating scores for balb_pu1_kla
# Integrating scores for balb_pu1_veh
# Integrating scores for c57bl6_cebpa_kla
# Integrating scores for c57bl6_cebpa_veh
# Integrating scores for c57bl6_pu1_kla
# Integrating scores for c57bl6_pu1_veh
# 	Max distance to merge: direct overlap required (-d given)
# 	Merging peaks...
# 	Comparing ./peak_files/balb_cebpa_kla_peaks.tsv (24836 total) and ./peak_files/balb_cebpa_kla_peaks.tsv (24836 total)
# 	Comparing ./peak_files/balb_cebpa_kla_peaks.tsv (24836 total) and ./peak_files/balb_cebpa_veh_peaks.tsv (23349 total)
# 	Comparing ./peak_files/balb_cebpa_kla_peaks.tsv (24836 total) and ./peak_files/balb_pu1_kla_peaks.tsv (60743 total)
# 	Comparing ./peak_files/balb_cebpa_kla_peaks.tsv (24836 total) and ./peak_files/balb_pu1_veh_peaks.tsv (58546 total)
# 	Comparing ./peak_files/balb_cebpa_kla_peaks.tsv (24836 total) and ./peak_files/c57bl6_cebpa_kla_peaks.tsv (23276 total)
# 	Comparing ./peak_files/balb_cebpa_kla_peaks.tsv (24836 total) and ./peak_files/c57bl6_cebpa_veh_peaks.tsv (19599 total)
# 	Comparing ./peak_files/balb_cebpa_kla_peaks.tsv (24836 total) and ./peak_files/c57bl6_pu1_kla_peaks.tsv (59749 total)
# 	Comparing ./peak_files/balb_cebpa_kla_peaks.tsv (24836 total) and ./peak_files/c57bl6_pu1_veh_peaks.tsv (53313 total)
# 	Comparing ./peak_files/balb_cebpa_veh_peaks.tsv (23349 total) and ./peak_files/balb_cebpa_kla_peaks.tsv (24836 total)
# 	Comparing ./peak_files/balb_cebpa_veh_peaks.tsv (23349 total) and ./peak_files/balb_cebpa_veh_peaks.tsv (23349 total)
# 	Comparing ./peak_files/balb_cebpa_veh_peaks.tsv (23349 total) and ./peak_files/balb_pu1_kla_peaks.tsv (60743 total)
# 	Comparing ./peak_files/balb_cebpa_veh_peaks.tsv (23349 total) and ./peak_files/balb_pu1_veh_peaks.tsv (58546 total)
# 	Comparing ./peak_files/balb_cebpa_veh_peaks.tsv (23349 total) and ./peak_files/c57bl6_cebpa_kla_peaks.tsv (23276 total)
# 	Comparing ./peak_files/balb_cebpa_veh_peaks.tsv (23349 total) and ./peak_files/c57bl6_cebpa_veh_peaks.tsv (19599 total)
# 	Comparing ./peak_files/balb_cebpa_veh_peaks.tsv (23349 total) and ./peak_files/c57bl6_pu1_kla_peaks.tsv (59749 total)
# 	Comparing ./peak_files/balb_cebpa_veh_peaks.tsv (23349 total) and ./peak_files/c57bl6_pu1_veh_peaks.tsv (53313 total)
# 	Comparing ./peak_files/balb_pu1_kla_peaks.tsv (60743 total) and ./peak_files/balb_cebpa_kla_peaks.tsv (24836 total)
# 	Comparing ./peak_files/balb_pu1_kla_peaks.tsv (60743 total) and ./peak_files/balb_cebpa_veh_peaks.tsv (23349 total)
# 	Comparing ./peak_files/balb_pu1_kla_peaks.tsv (60743 total) and ./peak_files/balb_pu1_kla_peaks.tsv (60743 total)
# 	Comparing ./peak_files/balb_pu1_kla_peaks.tsv (60743 total) and ./peak_files/balb_pu1_veh_peaks.tsv (58546 total)
# 	Comparing ./peak_files/balb_pu1_kla_peaks.tsv (60743 total) and ./peak_files/c57bl6_cebpa_kla_peaks.tsv (23276 total)
# 	Comparing ./peak_files/balb_pu1_kla_peaks.tsv (60743 total) and ./peak_files/c57bl6_cebpa_veh_peaks.tsv (19599 total)
# 	Comparing ./peak_files/balb_pu1_kla_peaks.tsv (60743 total) and ./peak_files/c57bl6_pu1_kla_peaks.tsv (59749 total)
# 	Comparing ./peak_files/balb_pu1_kla_peaks.tsv (60743 total) and ./peak_files/c57bl6_pu1_veh_peaks.tsv (53313 total)
# 	Comparing ./peak_files/balb_pu1_veh_peaks.tsv (58546 total) and ./peak_files/balb_cebpa_kla_peaks.tsv (24836 total)
# 	Comparing ./peak_files/balb_pu1_veh_peaks.tsv (58546 total) and ./peak_files/balb_cebpa_veh_peaks.tsv (23349 total)
# 	Comparing ./peak_files/balb_pu1_veh_peaks.tsv (58546 total) and ./peak_files/balb_pu1_kla_peaks.tsv (60743 total)
# 	Comparing ./peak_files/balb_pu1_veh_peaks.tsv (58546 total) and ./peak_files/balb_pu1_veh_peaks.tsv (58546 total)
# 	Comparing ./peak_files/balb_pu1_veh_peaks.tsv (58546 total) and ./peak_files/c57bl6_cebpa_kla_peaks.tsv (23276 total)
# 	Comparing ./peak_files/balb_pu1_veh_peaks.tsv (58546 total) and ./peak_files/c57bl6_cebpa_veh_peaks.tsv (19599 total)
# 	Comparing ./peak_files/balb_pu1_veh_peaks.tsv (58546 total) and ./peak_files/c57bl6_pu1_kla_peaks.tsv (59749 total)
# 	Comparing ./peak_files/balb_pu1_veh_peaks.tsv (58546 total) and ./peak_files/c57bl6_pu1_veh_peaks.tsv (53313 total)
# 	Comparing ./peak_files/c57bl6_cebpa_kla_peaks.tsv (23276 total) and ./peak_files/balb_cebpa_kla_peaks.tsv (24836 total)
# 	Comparing ./peak_files/c57bl6_cebpa_kla_peaks.tsv (23276 total) and ./peak_files/balb_cebpa_veh_peaks.tsv (23349 total)
# 	Comparing ./peak_files/c57bl6_cebpa_kla_peaks.tsv (23276 total) and ./peak_files/balb_pu1_kla_peaks.tsv (60743 total)
# 	Comparing ./peak_files/c57bl6_cebpa_kla_peaks.tsv (23276 total) and ./peak_files/balb_pu1_veh_peaks.tsv (58546 total)
# 	Comparing ./peak_files/c57bl6_cebpa_kla_peaks.tsv (23276 total) and ./peak_files/c57bl6_cebpa_kla_peaks.tsv (23276 total)
# 	Comparing ./peak_files/c57bl6_cebpa_kla_peaks.tsv (23276 total) and ./peak_files/c57bl6_cebpa_veh_peaks.tsv (19599 total)
# 	Comparing ./peak_files/c57bl6_cebpa_kla_peaks.tsv (23276 total) and ./peak_files/c57bl6_pu1_kla_peaks.tsv (59749 total)
# 	Comparing ./peak_files/c57bl6_cebpa_kla_peaks.tsv (23276 total) and ./peak_files/c57bl6_pu1_veh_peaks.tsv (53313 total)
# 	Comparing ./peak_files/c57bl6_cebpa_veh_peaks.tsv (19599 total) and ./peak_files/balb_cebpa_kla_peaks.tsv (24836 total)
# 	Comparing ./peak_files/c57bl6_cebpa_veh_peaks.tsv (19599 total) and ./peak_files/balb_cebpa_veh_peaks.tsv (23349 total)
# 	Comparing ./peak_files/c57bl6_cebpa_veh_peaks.tsv (19599 total) and ./peak_files/balb_pu1_kla_peaks.tsv (60743 total)
# 	Comparing ./peak_files/c57bl6_cebpa_veh_peaks.tsv (19599 total) and ./peak_files/balb_pu1_veh_peaks.tsv (58546 total)
# 	Comparing ./peak_files/c57bl6_cebpa_veh_peaks.tsv (19599 total) and ./peak_files/c57bl6_cebpa_kla_peaks.tsv (23276 total)
# 	Comparing ./peak_files/c57bl6_cebpa_veh_peaks.tsv (19599 total) and ./peak_files/c57bl6_cebpa_veh_peaks.tsv (19599 total)
# 	Comparing ./peak_files/c57bl6_cebpa_veh_peaks.tsv (19599 total) and ./peak_files/c57bl6_pu1_kla_peaks.tsv (59749 total)
# 	Comparing ./peak_files/c57bl6_cebpa_veh_peaks.tsv (19599 total) and ./peak_files/c57bl6_pu1_veh_peaks.tsv (53313 total)
# 	Comparing ./peak_files/c57bl6_pu1_kla_peaks.tsv (59749 total) and ./peak_files/balb_cebpa_kla_peaks.tsv (24836 total)
# 	Comparing ./peak_files/c57bl6_pu1_kla_peaks.tsv (59749 total) and ./peak_files/balb_cebpa_veh_peaks.tsv (23349 total)
# 	Comparing ./peak_files/c57bl6_pu1_kla_peaks.tsv (59749 total) and ./peak_files/balb_pu1_kla_peaks.tsv (60743 total)
# 	Comparing ./peak_files/c57bl6_pu1_kla_peaks.tsv (59749 total) and ./peak_files/balb_pu1_veh_peaks.tsv (58546 total)
# 	Comparing ./peak_files/c57bl6_pu1_kla_peaks.tsv (59749 total) and ./peak_files/c57bl6_cebpa_kla_peaks.tsv (23276 total)
# 	Comparing ./peak_files/c57bl6_pu1_kla_peaks.tsv (59749 total) and ./peak_files/c57bl6_cebpa_veh_peaks.tsv (19599 total)
# 	Comparing ./peak_files/c57bl6_pu1_kla_peaks.tsv (59749 total) and ./peak_files/c57bl6_pu1_kla_peaks.tsv (59749 total)
# 	Comparing ./peak_files/c57bl6_pu1_kla_peaks.tsv (59749 total) and ./peak_files/c57bl6_pu1_veh_peaks.tsv (53313 total)
# 	Comparing ./peak_files/c57bl6_pu1_veh_peaks.tsv (53313 total) and ./peak_files/balb_cebpa_kla_peaks.tsv (24836 total)
# 	Comparing ./peak_files/c57bl6_pu1_veh_peaks.tsv (53313 total) and ./peak_files/balb_cebpa_veh_peaks.tsv (23349 total)
# 	Comparing ./peak_files/c57bl6_pu1_veh_peaks.tsv (53313 total) and ./peak_files/balb_pu1_kla_peaks.tsv (60743 total)
# 	Comparing ./peak_files/c57bl6_pu1_veh_peaks.tsv (53313 total) and ./peak_files/balb_pu1_veh_peaks.tsv (58546 total)
# 	Comparing ./peak_files/c57bl6_pu1_veh_peaks.tsv (53313 total) and ./peak_files/c57bl6_cebpa_kla_peaks.tsv (23276 total)
# 	Comparing ./peak_files/c57bl6_pu1_veh_peaks.tsv (53313 total) and ./peak_files/c57bl6_cebpa_veh_peaks.tsv (19599 total)
# 	Comparing ./peak_files/c57bl6_pu1_veh_peaks.tsv (53313 total) and ./peak_files/c57bl6_pu1_kla_peaks.tsv (59749 total)
# 	Comparing ./peak_files/c57bl6_pu1_veh_peaks.tsv (53313 total) and ./peak_files/c57bl6_pu1_veh_peaks.tsv (53313 total)

# %% [markdown]
# ## Annotate Peak File

# %%
# %%bash
# annotatePeaks.pl ./group/merged_peaks.tsv mm10 > merged_annotated_peaks.tsv &

# %% [markdown]
# ## Retrieve Peak Sequences

# %%
# %%bash
# /home/jenhan/code/motif_tools/getTargetSequencesWrapper.sh ./group/ ./group 0
# Out:
# python extendPeaks.py ./group//merged_peaks.tsv ./group//merged_extPeaks.tsv 0
# homerTools extract ./group//merged_extPeaks.tsv /bioinformatics/homer/data/genomes/mm10 -fa > ./group/merged.fa
# 	Extracting sequences from directory: /bioinformatics/homer/data/genomes/mm10
# 	Extracting 6640 sequences from chr1
# 	Extracting 7677 sequences from chr2
# 	Extracting 4963 sequences from chr3
# 	Extracting 5370 sequences from chr4
# 	Extracting 5534 sequences from chr5
# 	Extracting 5464 sequences from chr6
# 	Extracting 5283 sequences from chr7
# 	Extracting 4314 sequences from chr8
# 	Extracting 4878 sequences from chr9
# 	Extracting 5302 sequences from chr10
# 	Extracting 6527 sequences from chr11
# 	Extracting 3727 sequences from chr12
# 	Extracting 4540 sequences from chr13
# 	Extracting 3674 sequences from chr14
# 	Extracting 3910 sequences from chr15
# 	Extracting 3459 sequences from chr16
# 	Extracting 4051 sequences from chr17
# 	Extracting 2779 sequences from chr18
# 	Extracting 3011 sequences from chr19
# 	Extracting 2156 sequences from chrX
# 	Extracting 2 sequences from chrY
# 	Extracting 5 sequences from chr4_GL456216_random
# 	Extracting 1 sequences from chr4_JH584295_random
# 	Extracting 1 sequences from chrUn_GL456359
# 	Extracting 1 sequences from chrUn_GL456370
# 	Extracting 2 sequences from chrUn_JH584304
# 	Extracting 3 sequences from chrX_GL456233_random

# %%
### read in sequences as dictionary {peakID: sequence}
with open('./group/merged.fa') as f:
    data = f.readlines()

_id_sequence_dict = {}
for line in data:
    if line[0] == '>':
        sequenceName = line.strip()[1:]
    else:
        _id_sequence_dict[sequenceName] = line.strip().upper()

# %% [markdown]
# ## Scan for Motifs using Fimo

# %%
# create a script to scan for motifs using FIMO
! if [ ! -d ./fimo_out/ ]; then mkdir ./fimo_out; fi
! if [ ! -d ./fimo_results/ ]; then mkdir ./fimo_results; fi


pthresh = 0.01
motif_dir = '/home/jenhan/analysis/cobinding_motif_analysis/fimo_motifs/'

fimo_results_dir = './fimo_results'
count = 0
scriptFile = open('scanMotifs.sh','w')
for m in os.listdir(motif_dir):
    if 'fimo' in m:
        fimo_out_dir = '/home/jenhan/analysis/strains_analysis/fimo_out/' + m.replace('.fimo','')
        outPath = fimo_results_dir + '/merged_'+ m.replace('.fimo','') +'.txt'
        scriptFile.write(
#             '(sleep ' + str(15 * count) + 
            '(sleep ' + str(0 * count) + 
            's; fimo --text --max-stored-scores 2000000 --output-pthresh ' + 
            str(pthresh) +' --oc ' + fimo_out_dir + ' ' +
            motif_dir + '/' + m + ' /home/jenhan/analysis/strains_analysis/group/merged.fa '+
            '> ' + outPath + ' ) & \n')
        count+=1
scriptFile.close()

# %%
# %%bash
# chmod a+x ./scanMotifs.sh
# ./scanMotifs.sh
# Out:
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +spib of width 7.
# Using motif -spib of width 7.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +duxa of width 13.
# Using motif -duxa of width 13.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +dux of width 8.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -dux of width 8.
# Read 1 motifs.
# Using motif +hoxa5 of width 8.
# Using motif +elk_etv of width 11.
# Using motif -hoxa5 of width 8.
# Using motif +ewsr1-fli1 of width 18.
# Using motif -elk_etv of width 11.
# Using motif -ewsr1-fli1 of width 18.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# FATAL: Error attempting to read motif ID 2.
#
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using motif +hes of width 12.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Using motif -hes of width 12.
# Using motif +rora of width 10.
# Using motif +mzf1 of width 6.
# Using motif -mzf1 of width 6.
# Using motif -rora of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Read 1 motifs.
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Read 1 motifs.
# Read 1 motifs.
# Read 1 motifs.
# Using motif +rfx of width 16.
# Using motif +rar of width 16.
# Using motif +prox1 of width 12.
# Using motif +rhox11 of width 17.
# Using motif +pax1_pax9 of width 17.
# Using motif +nr2_rxr of width 15.
# Using motif -prox1 of width 12.
# Using motif -rhox11 of width 17.
# Using motif -rfx of width 16.
# Using motif -rar of width 16.
# Using motif -pax1_pax9 of width 17.
# Using motif -nr2_rxr of width 15.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +nr2e1 of width 9.
# Using motif -nr2e1 of width 9.
# Using motif +nfyb of width 15.
# Using motif +irf2 of width 18.
# Using motif -nfyb of width 15.
# Using motif -irf2 of width 18.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +zbtb18 of width 13.
# Using motif -zbtb18 of width 13.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Using motif +pou6f2 of width 10.
# Using motif +pou1f1 of width 14.
# Using motif -pou6f2 of width 10.
# Using motif -pou1f1 of width 14.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +arnt_mycn of width 8.
# Using motif -arnt_mycn of width 8.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +arid3a of width 6.
# Using motif -arid3a of width 6.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +alx1_alx4_arx of width 17.
# Using motif -alx1_alx4_arx of width 17.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Using motif +rel of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Read 1 motifs.
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Read 1 motifs.
# Read 1 motifs.
# Using background frequencies from NR sequence database.
# Using background frequencies from NR sequence database.
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Read 1 motifs.
# Read 1 motifs.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +yy1 of width 12.
# Using motif +usf of width 11.
# Read 1 motifs.
# Read 1 motifs.
# Using motif +sp1 of width 11.
# Using motif +xbp1 of width 14.
# Using motif -yy1 of width 12.
# Using motif -usf of width 11.
# Using motif +t of width 16.
# Using motif +tfap2-3 of width 13.
# Using motif +tfcp2 of width 10.
# Using motif -sp1 of width 11.
# Using motif -xbp1 of width 14.
# Using motif -tfcp2 of width 10.
# Using motif -tfap2-3 of width 13.
# Using motif -t of width 16.
# Using motif -rel of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using motif +sox17 of width 9.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif -sox17 of width 9.
# Using motif +spi1-c of width 14.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +znf423 of width 15.
# Using motif -spi1-c of width 14.
# Using motif +zic of width 14.
# Using motif -znf423 of width 15.
# Using motif -zic of width 14.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using motif +stat1-3 of width 11.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif -stat1-3 of width 11.
# Using motif +ebf1 of width 14.
# Using motif -ebf1 of width 14.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +esrr of width 10.
# Using motif -esrr of width 10.
# Using motif +sox3_sox6 of width 10.
# Using motif +homeobox-5 of width 9.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif -homeobox-5 of width 9.
# Using motif -sox3_sox6 of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +tp53 of width 18.
# Using motif -tp53 of width 18.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +homeobox-1 of width 8.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Using motif -homeobox-1 of width 8.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +e2f2 of width 16.
# Using motif +dmrt3 of width 11.
# Using motif +bcl6 of width 14.
# Using motif -dmrt3 of width 11.
# Using motif -bcl6 of width 14.
# Using motif -e2f2 of width 16.
# Using motif +hoxa9 of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Read 1 motifs.
# Using motif -hoxa9 of width 11.
# Using motif +cdx of width 11.
# Using motif +dmbx1 of width 17.
# Using motif +bhlh of width 10.
# Using motif +bhlhe23 of width 12.
# Using motif +ascl2_nhlh1 of width 10.
# Using motif -bhlh of width 10.
# Using motif -cdx of width 11.
# Using motif -ascl2_nhlh1 of width 10.
# Using motif -bhlhe23 of width 12.
# Using motif -dmbx1 of width 17.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +nrf1 of width 11.
# Using motif -nrf1 of width 11.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +homeobox-4 of width 11.
# Warning: text mode turns off computation of q-values
# Using motif -homeobox-4 of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +mybl1 of width 12.
# Using motif -mybl1 of width 12.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +gfi1b of width 11.
# Using motif -gfi1b of width 11.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +e2f4_e2f6 of width 11.
# Using motif +mecom of width 14.
# Using motif -e2f4_e2f6 of width 11.
# Using motif +hltf of width 10.
# Using motif -mecom of width 14.
# Using motif -hltf of width 10.
# Warning: text mode turns off computation of q-values
# Using motif +e2f7 of width 14.
# Using motif -e2f7 of width 14.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +irf7-8-9 of width 15.
# Warning: text mode turns off computation of q-values
# Using motif -irf7-8-9 of width 15.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +sox5_sox9_sry of width 9.
# Using motif -sox5_sox9_sry of width 9.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +rreb1 of width 20.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif -rreb1 of width 20.
# Using motif +nfi of width 6.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -nfi of width 6.
# Read 1 motifs.
# Using motif +mef2c of width 15.
# Using motif -mef2c of width 15.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +lin54 of width 9.
# Using motif -lin54 of width 9.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +prdm1 of width 15.
# Warning: text mode turns off computation of q-values
# Using motif -prdm1 of width 15.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +fox of width 8.
# Using motif -fox of width 8.
# Using motif +nr4a2 of width 8.
# Using motif -nr4a2 of width 8.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +hoxc13 of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -hoxc13 of width 11.
# Read 1 motifs.
# Using motif +pknox_tgif of width 12.
# Warning: text mode turns off computation of q-values
# Using motif -pknox_tgif of width 12.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +rxravdr of width 15.
# Using motif -rxravdr of width 15.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +tp63 of width 18.
# Using motif -tp63 of width 18.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +gata of width 9.
# Warning: text mode turns off computation of q-values
# Using motif -gata of width 9.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +tcf7 of width 12.
# Using motif -tcf7 of width 12.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +hoxc9 of width 13.
# Using motif -hoxc9 of width 13.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +esr1 of width 17.
# Warning: text mode turns off computation of q-values
# Using motif -esr1 of width 17.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +onecut of width 14.
# Read 1 motifs.
# Using motif -onecut of width 14.
# Using motif +hnf4a of width 16.
# Using motif -hnf4a of width 16.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +nkx2-5var of width 11.
# Using motif -nkx2-5var of width 11.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +znf143 of width 16.
# Read 1 motifs.
# Using motif -znf143 of width 16.
# Warning: text mode turns off computation of q-values
# Using motif +pax5 of width 19.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif -pax5 of width 19.
# Using motif +hinfp of width 12.
# Warning: text mode turns off computation of q-values
# Using motif -hinfp of width 12.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +mzf1var of width 10.
# Using motif -mzf1var of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using motif +insm1 of width 12.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif -insm1 of width 12.
# Using motif +thap1 of width 9.
# Warning: text mode turns off computation of q-values
# Using motif -thap1 of width 9.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +stat6 of width 15.
# Using motif -stat6 of width 15.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +sox8 of width 16.
# Warning: text mode turns off computation of q-values
# Using motif -sox8 of width 16.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +sp4 of width 17.
# Warning: text mode turns off computation of q-values
# Using motif -sp4 of width 17.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +tp73 of width 18.
# Using motif -tp73 of width 18.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +mef2a-b-d of width 12.
# Using motif -mef2a-b-d of width 12.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +elf of width 12.
# Using motif +glis of width 14.
# Using motif -elf of width 12.
# Using motif +cebp of width 10.
# Using motif -glis of width 14.
# Using motif -cebp of width 10.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +cenpb of width 15.
# Using motif -cenpb of width 15.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +maf_nrl of width 12.
# Using motif -maf_nrl of width 12.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +rargvar of width 17.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -rargvar of width 17.
# Read 1 motifs.
# Using motif +srf of width 16.
# Warning: text mode turns off computation of q-values
# Using motif -srf of width 16.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +nkx2-5 of width 7.
# Using motif -nkx2-5 of width 7.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Warning: text mode turns off computation of q-values
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +nr5a2 of width 15.
# Using motif -nr5a2 of width 15.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +nr2f1 of width 13.
# Warning: text mode turns off computation of q-values
# Using motif -nr2f1 of width 13.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +pbx1 of width 12.
# Using motif -pbx1 of width 12.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +rar_rxr of width 17.
# Using motif -rar_rxr of width 17.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +ap-1 of width 7.
# Using motif -ap-1 of width 7.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +zfx of width 14.
# Using motif -zfx of width 14.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +sox2 of width 8.
# Using motif -sox2 of width 8.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +hnf1 of width 13.
# Warning: text mode turns off computation of q-values
# Using motif -hnf1 of width 13.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# FATAL: Error attempting to read motif ID 2.
#
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +crem of width 10.
# Read 1 motifs.
# Using motif +sox10 of width 6.
# Using motif -crem of width 10.
# Using motif -sox10 of width 6.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +irf1 of width 21.
# Read 1 motifs.
# Using motif +hoxb5_hoxd3 of width 16.
# Using motif -irf1 of width 21.
# Warning: text mode turns off computation of q-values
# Using motif -hoxb5_hoxd3 of width 16.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +cux of width 10.
# Using motif -cux of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +six3 of width 17.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif -six3 of width 17.
# Using motif +ar_nr3c1_nr3c2 of width 17.
# Using motif -ar_nr3c1_nr3c2 of width 17.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +hsf of width 13.
# Warning: text mode turns off computation of q-values
# Using motif -hsf of width 13.
# Using motif +arid3b of width 11.
# Using motif -arid3b of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +runx of width 11.
# Read 1 motifs.
# Using motif -runx of width 11.
# Using motif +mafg of width 21.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using motif -mafg of width 21.
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +klf of width 11.
# Using motif -klf of width 11.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +nfat of width 10.
# Warning: text mode turns off computation of q-values
# Using motif -nfat of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +pou2-3-5 of width 9.
# Using motif -pou2-3-5 of width 9.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +scrt of width 13.
# Warning: text mode turns off computation of q-values
# Using motif -scrt of width 13.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +ventx of width 9.
# Using motif -ventx of width 9.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +nkx2-3_nkx2-8 of width 10.
# Using motif -nkx2-3_nkx2-8 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +gmeb2 of width 8.
# Using motif -gmeb2 of width 8.
# Using motif +roravar of width 14.
# Warning: text mode turns off computation of q-values
# Using motif -roravar of width 14.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +tfap1 of width 12.
# Using motif -tfap1 of width 12.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +nfya of width 18.
# Warning: text mode turns off computation of q-values
# Using motif -nfya of width 18.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +mga_tbx of width 8.
# Using motif -mga_tbx of width 8.
# Using motif +zeb1 of width 9.
# Using motif -zeb1 of width 9.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +isl2_nkx3-1_nkx3-2 of width 9.
# Warning: text mode turns off computation of q-values
# Using motif -isl2_nkx3-1_nkx3-2 of width 9.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +gcm of width 10.
# Using motif -gcm of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Read 1 motifs.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +pparg of width 20.
# Using motif +e2f1 of width 12.
# Using motif +ctcf of width 19.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using motif -e2f1 of width 12.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif -pparg of width 20.
# Using motif -ctcf of width 19.
# Using motif +znf740 of width 10.
# Using motif -znf740 of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Using motif +zbed1 of width 13.
# Using motif +phox2_prop of width 11.
# Using motif -phox2_prop of width 11.
# Using motif -zbed1 of width 13.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +hnf4g of width 15.
# Using motif -hnf4g of width 15.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +hoxa11 of width 12.
# Warning: text mode turns off computation of q-values
# Using motif -hoxa11 of width 12.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +pparg_rxra of width 15.
# Using motif -pparg_rxra of width 15.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +rest of width 21.
# Using motif -rest of width 21.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +myc of width 10.
# Using motif -myc of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +nfil3 of width 11.
# Warning: text mode turns off computation of q-values
# Using motif -nfil3 of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +hic of width 9.
# Warning: text mode turns off computation of q-values
# Using motif -hic of width 9.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +zbtb7 of width 12.
# Using motif -zbtb7 of width 12.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +myog_tcf12 of width 11.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Using motif -myog_tcf12 of width 11.
# Using motif +yy2 of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -yy2 of width 11.
# Read 1 motifs.
# Using motif +egr of width 11.
# Warning: text mode turns off computation of q-values
# Using motif -egr of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +pax6 of width 14.
# Warning: text mode turns off computation of q-values
# Using motif -pax6 of width 14.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Read 1 motifs.
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +atf7_batf3_creb5 of width 12.
# Using motif +plag1 of width 14.
# Using motif -atf7_batf3_creb5 of width 12.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif -plag1 of width 14.
# Using motif +gli2 of width 12.
# Warning: text mode turns off computation of q-values
# Using motif -gli2 of width 12.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +znf354c of width 6.
# Using motif -znf354c of width 6.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +arntl_mitf of width 10.
# Using motif -arntl_mitf of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +gsc of width 10.
# Using motif -gsc of width 10.
# Using motif +figla_id4_snai2_tcf3_tcf4 of width 10.
# Using motif -figla_id4_snai2_tcf3_tcf4 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +bhlha15 of width 8.
# Using motif -bhlha15 of width 8.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +srebpf of width 10.
# Using motif -srebpf of width 10.
# Using motif +pou4 of width 16.
# Using motif -pou4 of width 16.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +tbp of width 15.
# Warning: text mode turns off computation of q-values
# Using motif -tbp of width 15.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +myb of width 10.
# Using motif -myb of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +hoxd8 of width 17.
# Warning: text mode turns off computation of q-values
# Using motif -hoxd8 of width 17.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +bcl6b of width 17.
# Warning: text mode turns off computation of q-values
# Using motif -bcl6b of width 17.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +e2f8 of width 12.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -e2f8 of width 12.
# Read 1 motifs.
# Using motif +gfi1 of width 10.
# Using motif -gfi1 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +nr2e3 of width 7.
# Warning: text mode turns off computation of q-values
# Using motif -nr2e3 of width 7.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +grhl1 of width 12.
# Using motif -grhl1 of width 12.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +pax2 of width 8.
# Warning: text mode turns off computation of q-values
# Using motif -pax2 of width 8.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +nfkb of width 13.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -nfkb of width 13.
# Read 1 motifs.
# Using motif +zbtb33 of width 15.
# Warning: text mode turns off computation of q-values
# Using motif -zbtb33 of width 15.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +spz1 of width 11.
# Warning: text mode turns off computation of q-values
# Using motif -spz1 of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +tcf21 of width 14.
# Warning: text mode turns off computation of q-values
# Using motif -tcf21 of width 14.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +mybl2 of width 15.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -mybl2 of width 15.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +znf263 of width 21.
# Warning: text mode turns off computation of q-values
# Using motif -znf263 of width 21.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +dux4 of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif -dux4 of width 11.
# Using motif +lef1 of width 15.
# Using motif -lef1 of width 15.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +pax3_pax7 of width 10.
# Using motif -pax3_pax7 of width 10.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Using motif +dbp_hlf_tef of width 11.
# Using motif -dbp_hlf_tef of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +sox1-l1-21-4 of width 16.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif -sox1-l1-21-4 of width 16.
# Using motif +creb3-l1 of width 14.
# Using motif +msc_myf6_tfap4 of width 10.
# Using motif -creb3-l1 of width 14.
# Using motif -msc_myf6_tfap4 of width 10.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +homeobox-3 of width 11.
# Using motif -homeobox-3 of width 11.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +lhx3 of width 13.
# Warning: text mode turns off computation of q-values
# Using motif -lhx3 of width 13.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +tead of width 8.
# Using motif -tead of width 8.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +tcfl5 of width 10.
# Using motif -tcfl5 of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +smad3 of width 10.
# Using motif -smad3 of width 10.
# Using motif +id2_mlxip of width 8.
# Using motif -id2_mlxip of width 8.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +mtf1 of width 14.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -mtf1 of width 14.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +arid5a of width 14.
# Warning: text mode turns off computation of q-values
# Using motif -arid5a of width 14.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +meis of width 8.
# Using motif -meis of width 8.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +znf410 of width 17.
# Using motif -znf410 of width 17.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using motif +esr2 of width 15.
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif -esr2 of width 15.
# Using motif +tbx of width 11.
# Using motif -tbx of width 11.

# %% [markdown]
# ## Read in Score Files

# %% [markdown]
# ### Read in peak scores

# %%
# read in peak data data
summary_frame = pd.read_csv('./group_summary.tsv' , sep='\t')
summary_frame = summary_frame.fillna('0')
for col in summary_frame.columns[5:]:
    floatValues = []
    for val in summary_frame[col].values.astype(str):
        if ',' in val:
            maxVal = np.max([float(x) for x in val.split(',')])
            floatValues.append(maxVal)
        else:
            floatValues.append(float(val))
    summary_frame[col] = floatValues
summary_frame.index = summary_frame['ID'].values

# remove peaks in unknown/random chromosomes
summary_frame = summary_frame[~summary_frame['chr'].str.contains('random')]
summary_frame = summary_frame[~summary_frame['chr'].str.contains('Un')]


_factors = sorted(list(set([x.split('_')[1] for x in summary_frame.columns if '_' in x])))
summary_frame.to_pickle('summary_frame.pickle')
scaler = sklearn.preprocessing.MinMaxScaler()
normed_summary_frame = pd.DataFrame(scaler.fit_transform(summary_frame.ix[:,5:]))
normed_summary_frame.columns = summary_frame.columns.values[5:]
normed_summary_frame.index = summary_frame.index.values

# %% [markdown]
# ### Read in motif scores

# %%
motif_dir = '/home/jenhan/analysis/cobinding_motif_analysis/fimo_motifs/'

peak_start_dict = dict(zip(summary_frame['ID'].values, summary_frame['start'].values))

motif_score_frame = summary_frame[['ID', 'Factors', 'chr']]
motif_score_frame.index=motif_score_frame['ID'].values

motif_sequence_frame = summary_frame[['ID', 'Factors', 'chr']]
motif_sequence_frame.index=motif_score_frame['ID'].values

motif_strand_frame = summary_frame[['ID', 'Factors', 'chr']]
motif_strand_frame.index=motif_score_frame['ID'].values

motif_start_frame = summary_frame[['ID', 'Factors', 'chr']]
motif_start_frame.index=motif_score_frame['ID'].values

motif_end_frame = summary_frame[['ID', 'Factors', 'chr']]
motif_end_frame.index=motif_score_frame['ID'].values

motif_count_frame = summary_frame[['ID', 'Factors', 'chr']]
motif_count_frame.index = motif_count_frame['ID'].values

counter=0
for m in sorted(os.listdir(motif_dir)):
    counter+=1
    if '.fimo' in m:
        print(counter,m)
        motif_results = './fimo_results//merged_' + m.replace('.fimo','') +'.txt'
        fimo_result_frame=pd.read_csv(motif_results, 
                                      skiprows=1,
                                      names=['motif_name', 
                                             'peak_id', 
                                             'start', 
                                             'stop', 
                                             'strand', 
                                             'score', 
                                             'pvalue', 
                                             'sequence'],
                                      sep='\t')
        motif_name = m.replace('.fimo','')
        id_score_dict = {}
        id_strand_dict = {}
        id_sequence_dict = {}
        id_start_dict = {}
        id_end_dict = {}
        id_count_dict = {}
        
        ids = fimo_result_frame['peak_id'].values
        scores = fimo_result_frame['score'].values
        strands = fimo_result_frame['strand'].values
        sequences = fimo_result_frame['sequence']
        starts = fimo_result_frame['start']
        ends = fimo_result_frame['stop']
        
        for i in range(len(ids)):
            currentScore = float(scores[i])
            currentSequence = sequences[i]
            currentStrand = strands[i]
            currentStart = int(starts[i])
            currentEnd = int(ends[i])
            if currentScore < 0.0:
                currentScore = 0.0
            if ids[i] in id_score_dict:
                if currentScore > id_score_dict[ids[i]]:
                    id_score_dict[ids[i]] = currentScore
                    id_sequence_dict[ids[i]] = currentSequence
                    id_strand_dict[ids[i]] = currentStrand
                    id_start_dict[ids[i]] = currentStart
                    id_end_dict[ids[i]] = currentEnd
                    id_count_dict[ids[i]] += 1
            else:
                id_score_dict[ids[i]] = currentScore
                id_sequence_dict[ids[i]] = currentSequence
                id_strand_dict[ids[i]] = currentStrand
                id_start_dict[ids[i]] = currentStart
                id_end_dict[ids[i]] = currentEnd
                id_count_dict[ids[i]] = 0
                
        motif_score_frame[motif_name] = [id_score_dict[x] if x in id_score_dict else 0 for x in motif_score_frame['ID'].values]
        motif_sequence_frame[motif_name] = [id_sequence_dict[x] if x in id_sequence_dict else '?' for x in motif_sequence_frame['ID'].values]
        motif_strand_frame[motif_name] = [id_strand_dict[x] if x in id_score_dict else '' for x in motif_strand_frame['ID'].values]
        motif_start_frame[motif_name] = [id_start_dict[x] + peak_start_dict[x] if x in id_start_dict else -1 for x in motif_start_frame['ID'].values]
        motif_end_frame[motif_name] = [id_end_dict[x] + peak_start_dict[x] if x in id_end_dict else -1 for x in motif_end_frame['ID'].values]
        motif_count_frame[motif_name] = [id_count_dict[x] if x in id_count_dict else 0 for x in motif_count_frame['ID'].values]


        
motif_score_frame.to_pickle('motif_score_frame.pickle')
motif_score_frame.to_csv('motif_scores.tsv', sep='\t', index=False)

motif_sequence_frame.to_pickle('motif_sequence_frame.pickle')
motif_sequence_frame.to_csv('motif_sequence.tsv', sep='\t', index=False)

motif_strand_frame.to_pickle('motif_strand_frame.pickle')
motif_strand_frame.to_csv('motif_strand.tsv', sep='\t', index=False)

motif_start_frame.to_pickle('motif_start_frame.pickle')
motif_start_frame.to_csv('motif_start_frame.tsv', sep='\t', index=False)

motif_end_frame.to_pickle('motif_end_frame.pickle')
motif_end_frame.to_csv('motif_end_frame.tsv', sep='\t', index=False)

motif_count_frame.to_pickle('motif_count_frame.pickle')
motif_count_frame.to_csv('motif_count_frame.tsv', sep='\t', index=False)

scaler = preprocessing.MinMaxScaler()
normed_motif_frame = pd.DataFrame(scaler.fit_transform(motif_score_frame.ix[:,3:]))
normed_motif_frame.columns = motif_score_frame.columns.values[3:]
normed_motif_frame.index = motif_score_frame.index.values

scaled_motif_frame = pd.DataFrame()
for m in motif_score_frame.columns[3:]:
    scaled_motif_frame[m] = motif_score_frame[m]/(2*motif_sequence_frame[m].str.len().max())
# Out:
# 1 alx1_alx4_arx.fimo
# 2 ap-1.fimo
# 3 ar_nr3c1_nr3c2.fimo
# 4 arid3a.fimo
# 5 arid3b.fimo
# 6 arid5a.fimo
# 7 arnt_mycn.fimo
# 8

# %%
scaled_motif_frame
# Out:
#                           alx1_alx4_arx      ap-1  ar_nr3c1_nr3c2    arid3a  \
# Merged-chr17-34627665-3        0.125804  0.000000        0.000000  0.508086
# Merged-chr16-57200743-3        0.053001  0.924300        0.000000  0.508086
# Merged-chr9-70560828-3         0.000000  0.243004        0.027416  0.778647
# Merged-chr5-30893945-3         0.000000  0.000000        0.000000  0.038584
# Merged-chr16-87636040-3        0.000000  0.643352        0.310815  0.500128
# Merged-chr7-98535313-3         0.058601  0.243004        0.000000  0.000000
# Merged-chr13-67484493-3        0.170606  0.243004        0.024524  0.635408
# Merged-chr3-90604533-3         0.000000  0.530974        0.000000  0.834350
# Merged-chr17-26676427-3        0.000000  0.250028        0.000000  0.778647
# Merged-chr1-97769642-3         0.263009  0.000000        0.000000  0.452382
# Merged-chr7-104446416-3        0.000000  0.250028        0.000000  0.635408
# Merged-chr11-102156353-3       0.106203  0.243004        0.270330  0.046542
# Merged-chr7-59027671-3         0.243409  0.924300        0.093928  0.691113
# Merged-chr4-41319130-3         0.030600  0.243004        0.000000  0.834350
# Merged-chr11-119602934-4       0.176206  0.000000        0.082361  0.452382
# Merged-chr12-73907835-4        0.078202  0.000000        0.000000  0.000000
# Merged-chr11-17212255-4        0.000000  0.000000        0.160441  0.102245
# Merged-chr10-81545316-4        0.041800  0.000000        0.000000  0.000000
# Merged-chr7-12978159-4         0.000000  0.250028        0.000000  0.000000
# Merged-chr7-127288968-4        0.111803  0.924300        0.000000  0.102245
# Merged-chr4-116687122-4        0.240608  0.000000        0.000000  0.635408
# Merged-chr15-67397489-4        0.025000  0.250028        0.000000  0.508086
# Merged-chr9-44965654-4         0.008199  0.243004        0.000000  0.000000
# Merged-chr12-40681338-4        0.179006  0.243004        0.000000  0.452382
# Merged-chr2-29827837-4         0.033400  0.000000        0.000000  0.000000
# Merged-chr1-131529086-4        0.078202  0.643352        0.000000  0.173864
# Merged-chr5-149267158-4        0.027800  0.000000        0.041875  0.046542
# Merged-chr14-25694037-4        0.137004  0.250028        0.000000  0.452382
# Merged-chr6-4004262-4          0.000000  0.000000        0.000000  0.834350
# Merged-chr11-73128611-4        0.153805  0.250028        0.000000  0.078372
# ...                                 ...       ...             ...       ...
# Merged-chr6-113442528-7        0.010999  0.243004        0.000000  0.078372
# Merged-chr6-122602425-7        0.000000  0.000000        0.000000  0.500128
# Merged-chr7-126625610-7        0.041800  0.250028        0.000000  0.000000
# Merged-chr19-44009097-7        0.061401  0.250028        0.000000  0.500128
# Merged-chr5-125183792-7        0.000000  0.243004        0.000000  0.173864
# Merged-chr6-97856502-7    0.465405  0.348533   0.666181    0.642055
#
#                           ascl2_nhlh1  atf7_batf3_creb5        ...         \
# Merged-chr17-34627665-3      0.304938          0.000000        ...
# Merged-chr16-57200743-3      0.329444          0.000000        ...
# Merged-chr9-70560828-3       0.314740          0.000000        ...
# Merged-chr5-30893945-3       0.167705          0.000000        ...
# Merged-chr16-87636040-3      0.226519          0.574300        ...
# Merged-chr7-98535313-3       0.270629          0.251354        ...
# Merged-chr13-67484493-3      0.211815          0.615179        ...
# Merged-chr3-90604533-3       0.589210          0.000000        ...
# Merged-chr17-26676427-3      0.285334          0.000000        ...
# Merged-chr1-97769642-3       0.309839          0.000000        ...
# Merged-chr7-104446416-3      0.471579          0.296322        ...
# Merged-chr11-102156353-3     0.500985          0.000000        ...
# Merged-chr7-59027671-3       0.466678          0.312673        ...
# Merged-chr4-41319130-3       0.241222          0.091925        ...
# Merged-chr11-119602934-4     0.231420          0.059222        ...
# Merged-chr12-73907835-4      0.309839          0.000000        ...
# Merged-chr11-17212255-4      0.505885          0.000000        ...
# Merged-chr10-81545316-4      0.255926          0.000000        ...
# Merged-chr7-12978159-4       0.437271          0.026518        ...
# Merged-chr7-127288968-4      0.157902          0.000000        ...
# Merged-chr4-116687122-4      0.295135          0.000000        ...
# Merged-chr15-67397489-4      0.123593          0.000000        ...
# Merged-chr9-44965654-4       0.373555          0.431225        ...
# Merged-chr12-40681338-4      0.329444          0.000000        ...
# Merged-chr2-29827837-4       0.020668          0.000000        ...
# Merged-chr1-131529086-4      0.030471          0.210475        ...
# Merged-chr5-149267158-4      0.172605          0.000000        ...
# Merged-chr14-25694037-4      0.167705          0.000000        ...
# Merged-chr6-4004262-4        0.300037          0.000000        ...
# Merged-chr11-73128611-4      0.182408          0.000000        ...
# ...                               ...               ...        ...
# Merged-chr6-113442528-7      0.138297          0.000000        ...
# Merged-chr6-122602425-7      0.437271          0.000000        ...
# Merged-chr7-126625610-7      0.496085          0.000000        ...
# Merged-chr19-44009097-7      0.378456          0.000000        ...
# Merged-chr5-125183792-7      0.363753          0.000000        ...
# Merged-chr16-11001914-7      0.476480          0.000000        ...
# Merged-chr16-91849137-7      0.339247          0.000000        ...
# Merged-chr5-53454878-7       0.309839          0.000000        ...
# Merged-chr8-125012803-7      0.388258          0.000000        ...
# Merged-chr8-72303875-7       0.500985          0.000000        ...
# Merged-chr6-21959109-7       0.667625          0.000000        ...
# Merged-chr14-98116829-7      0.221617          0.018342        ...
# Merged-chr11-83082970-7      0.329444          0.051046        ...
# Merged-chr10-81291937-7      0.295135          0.014254        ...
# Merged-chr11-116433774-7     0.319642          0.235003        ...
# Merged-chr13-3541637-7       0.255926          0.000000        ...
# Merged-chr5-120558954-7      0.603910          0.000000        ...
# Merged-chr1-162570598-7      0.481382          0.000000        ...
# Merged-chr7-19149543-7       0.437271          0.000000        ...
# Merged-chr1-182108730-7      0.251025          0.051046        ...
# Merged-chr13-67484493-3   0.046104  0.621088  0.000000  0.000000  0.000000
# Merged-chr3-90604533-3    0.332264  0.694836  0.000000  0.009819  0.429281
# Merged-chr17-26676427-3   0.426881  0.858717  0.000000  0.294979  0.342535
# Merged-chr1-97769642-3    0.156875  0.858717  0.000000  0.039319  0.393794
# Merged-chr7-104446416-3   0.286110  0.703030  0.000000  0.000000  0.519970
# Merged-chr11-102156353-3  0.170722  0.678447  0.000000  0.176982  0.598830
# Merged-chr7-59027671-3    0.205338  0.621088  0.000000  0.000000  0.050755
# Merged-chr4-41319130-3    0.443036  0.776778  0.000000  0.065540  0.460825
# Merged-chr11-119602934-4  0.323033  0.858717  0.000000  0.000000  0.417452
# Merged-chr12-73907835-4   0.320726  0.678447  0.000000  0.000000  0.859065
# Merged-chr11-17212255-4   0.431498  0.776778  0.000000  0.000000  0.255790
# Merged-chr10-81545316-4   0.235339  0.776778  0.000000  0.000000  0.504195
# Merged-chr7-12978159-4    0.131490  0.670253  0.000000  0.000000  0.602770
# Merged-chr7-127288968-4   0.463805  0.678447  0.000000  0.000000  0.780205
# Merged-chr4-116687122-4   0.281493  0.858717  0.000000  0.000000  0.247903
# Merged-chr15-67397489-4   0.080720  0.776778  0.000000  0.000000  0.224246
# Merged-chr9-44965654-4    0.263031  0.678447  0.000000  0.000000  0.598830
# Merged-chr12-40681338-4   0.161491  0.670253  0.000000  0.000000  0.086241
# Merged-chr2-29827837-4    0.154568  0.375262  0.000000  0.000000  0.058641
# Merged-chr1-131529086-4   0.048411  0.694836  0.000000  0.000000  0.389851
# Merged-chr5-149267158-4   0.475345  0.596505  0.000000  0.000000  0.504195
# Merged-chr14-25694037-4   0.239955  0.858717  0.000000  0.045874  0.859065
# Merged-chr6-4004262-4     0.274571  0.530952  0.000000  0.000000  0.425338
# Merged-chr11-73128611-4   0.173030  0.858717  0.000000  0.000000  0.342535
# ...                            ...       ...       ...       ...       ...
# Merged-chr6-113442528-7   0.115336  0.858717  0.000000  0.000000  0.145386
# Merged-chr6-122602425-7   0.276879  0.694836  0.000000  0.000000  0.780205
# Merged-chr7-126625610-7   0.586117  0.694836  0.000000  0.000000  0.476597
# Merged-chr19-44009097-7   0.226108  0.375262  0.000000  0.000000  0.000000
# Merged-chr5-125183792-7   0.306879  0.858717  0.000000  0.000000  0.519970
# Merged-chr16-11001914-7   0.288417  0.776778  0.000000  0.272035  0.626430
# Merged-chr16-91849137-7   0.295340  0.154018  0.000000  0.000000  0.287334
# Merged-chr5-53454878-7    0.186876  0.703030  0.000000  0.062263  0.196645
# Merged-chr8-125012803-7   0.304571  0.703030  0.000000  0.000000  0.307048
# Merged-chr8-72303875-7    0.299955  0.621088  0.000000  0.016375  0.563340
# Merged-chr6-21959109-7    0.306879  0.694836  0.000000  0.000000  0.429281
# Merged-chr14-98116829-7   0.143029  0.678447  0.264730  0.000000  0.192702
# Merged-chr11-83082970-7   0.228415  0.621088  0.000000  0.000000  0.318877
# Merged-chr10-81291937-7   0.200723  0.776778  0.000000  0.000000  0.228188
# Merged-chr11-116433774-7  0.161491  0.858717  0.000000  0.000000  0.701345
# Merged-chr13-3541637-7    0.113028  0.678447  0.000000  0.000000  0.121728
# Merged-chr5-120558954-7   0.336879  0.858717  0.000000  0.022930  0.665860
# Merged-chr1-162570598-7   0.493807  0.539146  0.000000  0.000000  0.598830
# Merged-chr7-19149543-7    0.184568  0.858717  0.000000  0.026208  0.460825
# Merged-chr1-182108730-7   0.283802  0.703030  0.000000  0.000000  0.330706
# Merged-chr10-80702354-7   0.316110  0.858717  0.000000  0.150761  0.571230
# Merged-chr5-151368615-7   0.200723  0.858717  0.000000  0.000000  0.437167
# Merged-chr17-74570654-7   0.055335  0.383456  0.000000  0.000000  0.283390
# Merged-chr10-26564705-7   0.276879  0.858717  0.000000  0.216314  0.701345
# Merged-chr14-17414520-7   0.078412  0.670253  0.000000  0.000000  0.267618
# Merged-chr7-4239319-7     0.332264  0.850525  0.000000  0.032763  0.322820
# Merged-chr10-81303724-7   0.429190  0.858717  0.000000  0.249091  0.594885
# Merged-chr10-80051910-7   0.500729  0.678447  0.000000  0.278591  0.831465
# Merged-chr2-132229938-7   0.473036  0.858717  0.000000  0.000000  0.165101
# Merged-chr6-97856502-7    0.156875  0.678447  0.105671  0.363810  0.496312
#
# [93261 rows x 196 columns]

# %% [markdown]
# ## Make Truth Table

# %%
motif_1 = 'spi1-c'
motif_2 = 'cebp'
factor_1 = 'c57bl6_pu1_veh'
factor_2 = 'c57bl6_cebpa_veh'

motif_state_1s = []
motif_state_2s = []
peak_state_1s = []
peak_state_2s = []
snp_state_1s = []
snp_state_2s = []
counts = []
for peak_state_1 in [True, False]:
    for peak_state_2 in [True, False]:
        for motif_state_1 in [True, False]:
            for motif_state_2 in [True, False]:
                motif_state_1s.append(motif_state_1)
                motif_state_2s.append(motif_state_2)
                peak_state_1s.append(peak_state_1)
                peak_state_2s.append(peak_state_2)

                peak_indices = summary_frame[(summary_frame['Factors'].str.contains(factor_1) == peak_state_1) &
                                             (summary_frame['Factors'].str.contains(factor_2) == peak_state_2)].index.values

                current_motif_frame = motif_score_frame[motif_score_frame.index.isin(peak_indices)]
                motif_indices = current_motif_frame[((current_motif_frame[motif_1] > 0) == motif_state_1) &
                                                    ((current_motif_frame[motif_2] > 0) == motif_state_2)].index.values                   

                count = len(motif_indices)
                counts.append(count)
current_count_frame = pd.DataFrame({factor_1 +' binding':peak_state_1s,
                                   factor_2 +' binding':peak_state_2s,
                                   motif_1 + ' motif':motif_state_1s,
                                   motif_2 + ' motif':motif_state_2s,

                                   'num peaks': counts})               
current_count_frame = current_count_frame[[factor_1 +' binding',
                                   factor_2 +' binding',
                                   motif_1 + ' motif',
                                   motif_2 + ' motif',
                                                                      'num peaks']]

# %%
current_count_frame.to_csv('cebpa_pu1_truthTable.tsv', sep='\t')
