# %% [markdown]
# # MTP Analysis

# %%
### header ###
__author__ = "Jenhan Tao"
__license__ = "BSD"
__email__ = "jenhantao@gmail.com"
# %load_ext autoreload
# %autoreload 2

# %%
### imports ###
import sys
import os
import pandas as pd
import numpy as np
import argparse
import matplotlib
import itertools
import scipy
import matplotlib.pyplot as plt 
import seaborn as sns
from IPython.display import Image, display
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import linkage, dendrogram
import scipy
import sklearn
from sklearn import preprocessing
from sklearn import decomposition
from mpl_toolkits.mplot3d import Axes3D
from matplotlib_venn import venn3, venn2
import pickle
from matplotlib import patches as mpatches
# %matplotlib inline
matplotlib.pylab.rcParams['savefig.dpi'] = 200
sys.setrecursionlimit(3000)
sns.set_context('notebook')

# %% [markdown]
# ## Preprocessing

# %%
# file directories
workingDirectory = '/home/jenhan/analysis/dhcr24_MTP_analysis/'
binDirectory = '/home/jenhan/bin/'
genomePath = '/bioinformatics/homer/data/genomes/mm10'
genomes = ['hg19','mm10', 'hg38']
peakDirectory = workingDirectory + 'peaks/'
scratchDirectory = workingDirectory + '/scratch/'
logFilePath = workingDirectory + '/log_files/'
tagDirPath = workingDirectory + '/tag_directories/'
inputDirectory = workingDirectory + '/input/'
idrDirectory = workingDirectory + '/idr/'

# tagDirPath = workingDirectory + '/all_tag_directories/'
# logFilePath = workingDirectory + '/all_log_files/'




os.chdir(workingDirectory)

# map ugly file names to prettier looking file names
# if not os.path.isfile("nameMapping.tsv"):
nameMappingFile = open("nameMapping.tsv", "w")
for f in os.listdir(logFilePath):
    rootName = f
    for gen in genomes:
        rootName = rootName.replace('.' + gen + '.star.log','').replace('.' +gen + '.bowtie2.log','')
    nameMappingFile.write(rootName + '\t' + rootName + '\n')
nameMappingFile.close()

# read in and parse name mapping file and create a DataFrame representation
with open("nameMapping.tsv") as f:
    data = f.readlines()
strains = []
treatments = []
owners = []
dates = []
originalNames = []
cleanedNames = []
for line in data:
    tokens = line.strip().split("\t")
    originalName = tokens[0]
    metaDataTokens = tokens[1].split('_')
    
    originalNames.append(originalName)
    cleanedNames.append(tokens[1])
    # grab metadata from string tokens
    strain = metaDataTokens[0].strip().split('-')[0]
    treatment = metaDataTokens[2].strip()
    owner = metaDataTokens[3].strip()
    date = metaDataTokens[4].strip()
    
    # append to overall lists
    strains.append(strain)
    treatments.append(treatment)
    owners.append(owner)
    dates.append(date)
    
metadata_frame = pd.DataFrame([strains, 
                                  treatments, 
                                  owners, 
                                  originalNames, 
                                  cleanedNames]).transpose()
metadata_frame.columns = ['strain', 
                         'treatment', 
                         'owner', 
                         'originalName', 
                         'sampleName']

simpleTreatments = []
for t in list(metadata_frame['treatment'].values):
    st = ''.join([x for x in t.split('-')])
    simpleTreatments.append(st)
metadata_frame['simpleTreatment'] = simpleTreatments

# create dictionary for convenience
originalName_cleanedName_dict = dict(zip(metadata_frame["originalName"], metadata_frame["sampleName"])) # {originalName:newName}
cleanedName_originalName_dict = dict(zip(metadata_frame["sampleName"], metadata_frame["originalName"])) # {newName:originalName}

### read in log files ###

# create data frame summarizing mapping quality logs
_totalReads = []
_unpairedReads = []
_unmappedReads = []
_uniquelyMappedReads = []
_multiMappedReads = []
_originalNames =[]
# from tagInfo.txt
_fragmentLengthEstimate =[]
_peakSizeEstimate = []
_tagsPerBP = []
_averageTagsPerPosition = []
_averageTagLength = []
_averageFragmentGCcontent = []

for logFile in os.listdir(logFilePath):
    with open(logFilePath + '/' + logFile) as f:
        data = f.readlines()
    rootName = logFile
    for gen in genomes:
        rootName = rootName.replace('.' + gen + '.star.log','').replace('.' +gen + '.bowtie2.log','')
    totalReads = int(data[5].split()[5])
    uniquelyMappedReads = int(data[8].split()[5])
    multiMappedReads = int(data[23].split()[8])
    unmappedReads = totalReads - uniquelyMappedReads - multiMappedReads
#     pbc = float(data[-1].split()[-1])

    _originalNames.append(rootName)
    _totalReads.append(totalReads)
    _unmappedReads.append(unmappedReads)
    _uniquelyMappedReads.append(uniquelyMappedReads)
    _multiMappedReads.append(multiMappedReads)
for tagdir in os.listdir(tagDirPath):
    with open(tagDirPath + '/' + tagdir + '/tagInfo.txt') as f:
        data = f.readlines()
        _fragmentLengthEstimate.append(float(data[2].strip().split('=')[1]))
        _peakSizeEstimate.append(float(data[3].strip().split('=')[1]))
        _tagsPerBP.append(float(data[4].strip().split('=')[1]))
        _averageTagsPerPosition.append(float(data[5].strip().split('=')[1]))
        _averageTagLength.append(float(data[6].strip().split('=')[1]))
        _averageFragmentGCcontent.append(float(data[8].strip().split('=')[1]))
mappingStats_frame = pd.DataFrame([_originalNames,
                                   _totalReads, 
                                   _unpairedReads, 
                                   _unmappedReads, 
                                   _uniquelyMappedReads, 
                                   _multiMappedReads,
                                   _fragmentLengthEstimate,
                                   _peakSizeEstimate,
                                   _tagsPerBP,
                                   _averageTagsPerPosition,
                                   _averageTagLength,
                                   _averageFragmentGCcontent,
                                  ]).transpose()
mappingStats_frame.columns = ['originalName',
                              'totalReads', 
                              'unpairedReads', 
                              'unmappedReads', 
                              'uniquelyMappedReads', 
                              'multiMappedReads',
                              'fragmentLengthEstimate',
                              'peakSizeEstimate',
                              'tagsPerBP',
                              'averageTagsPerPosition',
                              'averageTagLength',
                              'averageFragmentGCcontent']

# calculate fractions from read counts
mappingStats_frame['uniquelyMappedFraction'] = mappingStats_frame['uniquelyMappedReads'] / mappingStats_frame['totalReads']
mappingStats_frame['mappedFraction'] = (mappingStats_frame['uniquelyMappedReads'] + mappingStats_frame['multiMappedReads']) / mappingStats_frame['totalReads']


summary_frame = metadata_frame.merge(mappingStats_frame, on='originalName')


summary_frame.index  = pd.MultiIndex.from_arrays([list(summary_frame['strain'].values), list(summary_frame['simpleTreatment'].values)])
summary_frame = summary_frame.sort()
summary_frame.to_csv('qc_metrics.tsv', sep='\t', index=False)

# %% [markdown]
# ## Mapping Quality Control

# %% [markdown]
# ### Plot Distributions of Mapping Statistics

# %%
# plot distribution of uniquely mapped reads
sns.distplot(summary_frame['uniquelyMappedFraction'], bins=20, kde=False)
plt.title('Distribution of Fraction of Uniquely Mapped Reads per Sample (Pre-filtering)')
plt.xlabel('Uniquely Mapped Reads Fraction')
plt.ylabel('Frequency')
plt.show()

# Distribution of Uniquely Mapped Reads per Sample
sns.distplot(summary_frame['uniquelyMappedReads'], bins=20, kde=False)
plt.title('Distribution of Uniquely Mapped Reads per Sample (Pre-filtering)')
plt.xlabel('Total Reads')
plt.ylabel('Frequency')
plt.show()

plt.scatter(summary_frame['totalReads'], y=summary_frame['uniquelyMappedReads'])
plt.xlabel('totalReads')
plt.ylabel('uniquelyMappedReads')
plt.show()

sns.distplot(summary_frame['averageTagsPerPosition'], bins=20)
plt.xlabel('Clonality')
plt.show()

sns.distplot(summary_frame['averageFragmentGCcontent'], bins=20)
plt.xlabel('GC Content')
plt.show()

# %% [markdown]
# ### Filter Samples According to Mapping Quality

# %%
# filter samples according to threshold for the fraction of uniquely mapped reads
mappedFractionThreshold = 0.00
uniquelyMappedReadThreshold = 5000000
pbcThreshold=0.0
gcThreshold=0.10
clonalityThreshold = 3.0
# spotThreshold = 0.005

filtered_summary_frame = summary_frame.copy()
# filter on fraction of mapped reads
filtered_summary_frame = filtered_summary_frame[filtered_summary_frame['uniquelyMappedFraction'] >= mappedFractionThreshold]
# filter on total mapped reads
filtered_summary_frame = filtered_summary_frame[filtered_summary_frame['uniquelyMappedReads'] >= uniquelyMappedReadThreshold]

filtered_summary_frame = filtered_summary_frame[np.abs(filtered_summary_frame['averageFragmentGCcontent'] - 0.5) <=gcThreshold]

filtered_summary_frame = filtered_summary_frame[filtered_summary_frame['averageTagsPerPosition'] <= clonalityThreshold]


# get samples that were discarded
discardedSampleNames = [x for x in summary_frame['sampleName'].values if not x in filtered_summary_frame['sampleName'].values]
discarded_summary_frame = summary_frame[summary_frame['sampleName'].isin(discardedSampleNames)]
print("Number of Samples:", summary_frame.shape[0])
print("Number of discarded samples:",discarded_summary_frame.shape[0])
print("Number of Samples remaining after filtering:", filtered_summary_frame.shape[0])

# generate simplified name for naming output files
factorTreatment_count_dict = {} #{factor-treatment:count}
simplifiedNames = []
simpleTreatmentCombos = filtered_summary_frame["strain"].values + '_' +filtered_summary_frame["simpleTreatment"].values
for simpleNameRoot in simpleTreatmentCombos:
    if not simpleNameRoot in factorTreatment_count_dict:
        factorTreatment_count_dict[simpleNameRoot] = 1
    else:
        factorTreatment_count_dict[simpleNameRoot] += 1
    simplifiedName = (simpleNameRoot + '_' + str(factorTreatment_count_dict[simpleNameRoot]))
    simplifiedNames.append(simplifiedName)

filtered_summary_frame["simplifiedName"] = simplifiedNames
sampleName_simpleName_dict = dict(zip(filtered_summary_frame["sampleName"], filtered_summary_frame["simplifiedName"])) # {newName:simplifiedName}
simpleName_sampleName_dict = dict(zip(filtered_summary_frame["simplifiedName"], filtered_summary_frame["sampleName"])) # {simplifiedName:newName}

originalName_simpleName_dict = dict(zip(filtered_summary_frame["originalName"], filtered_summary_frame["simplifiedName"]))
simpleName_originalName_dict = dict(zip(filtered_summary_frame["simplifiedName"], filtered_summary_frame["originalName"])) 

filtered_summary_frame.to_csv('filtered_qc_metrics.tsv', sep='\t', index=False)
# Out:
# Number of Samples: 48
# Number of discarded samples: 7
# Number of Samples remaining after filtering: 41

# %%
# remove 24-veh, 012-mepip
filtered_summary_frame = filtered_summary_frame[filtered_summary_frame['originalName'] != 'Human-HMDM-MTP-024_RNA_VEH_EDM_15-12-09']

# %%
sns.distplot(filtered_summary_frame['uniquelyMappedFraction'], bins=20, kde=False, color='lightgreen')
plt.title('Distribution of Fraction of Uniquely Mapped Reads per Sample (Pre-filtering)')
plt.xlabel('Uniquely Mapped Reads Fraction')
plt.ylabel('Frequency')
plt.show()

# Distribution of Uniquely Mapped Reads per Sample
sns.distplot(filtered_summary_frame['uniquelyMappedReads'], bins=20, kde=False, color='lightgreen')
plt.title('Distribution of Uniquely Mapped Reads per Sample (Pre-filtering)')
plt.xlabel('Total Reads')
plt.ylabel('Frequency')
plt.show()

plt.scatter(filtered_summary_frame['totalReads'], y=filtered_summary_frame['uniquelyMappedReads'], color='lightgreen')
plt.ylabel('totalReads')
plt.xlabel('uniquelyMappedReads')
plt.show()

# %% [markdown]
# ## Calculate Tag Counts and RPKM

# %%
# %%capture
filteredTagDirectories = ' '.join([tagDirPath +x for x in filtered_summary_frame['originalName']])
# !analyzeRepeats.pl rna hg38 -count exons -condenseGenes -rpkm -d $filteredTagDirectories > rpkm.tsv
# !analyzeRepeats.pl rna hg38 -count exons -condenseGenes -noadj -d $filteredTagDirectories > raw.tsv
# !analyzeRepeats.pl rna hg38 -count exons -condenseGenes -d $filteredTagDirectories > normed.tsv

# !analyzeRepeats.pl rna hg38 -count exons -condenseGenes -rpkm -d ./tag_directories/* > rpkm_all.tsv
# Out:
# 	Tag Directories:
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_DMHCA_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_DMHCA_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_DMHCA_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_DMHCA_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_DMHCA_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_DMHCA_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Des_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_Des_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Des_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Des_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Des_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Des_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_GW_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_GW_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_GW_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_GW_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_GW_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_GW_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Vehicle_EDM_15-12-09
# 	Input file format: homerRmsk
# 	Filtering based on repeat parameters: kept 56082 of 56082
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Vehicle_EDM_15-12-09
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 	Printing output
# 		Printed 26003 of 48436 repeats (expression >= -1e+20)
# 	Tag Directories:
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_DMHCA_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_DMHCA_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_DMHCA_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_DMHCA_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_DMHCA_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_DMHCA_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Des_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_Des_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Des_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Des_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Des_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Des_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_GW_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_GW_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_GW_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_GW_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_GW_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_GW_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Vehicle_EDM_15-12-09
# 	Input file format: homerRmsk
# 	Filtering based on repeat parameters: kept 56082 of 56082
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Vehicle_EDM_15-12-09
# 	Printing output
# 		Printed 26003 of 48436 repeats (expression >= -1e+20)
# 	Tag Directories:
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_DMHCA_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_DMHCA_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_DMHCA_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_DMHCA_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_DMHCA_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_DMHCA_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Des_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_Des_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Des_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Des_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Des_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Des_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_GW_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_GW_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_GW_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_GW_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_GW_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_GW_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Mepip_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_T09_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_Vehicle_EDM_15-12-09
# 		/home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Vehicle_EDM_15-12-09
# 	Input file format: homerRmsk
# 	Filtering based on repeat parameters: kept 56082 of 56082
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Vehicle_EDM_15-12-09
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 	Printing output
# 		Printed 26003 of 48436 repeats (expression >= -1e+20)
# 	Tag Directories:
# 		./tag_directories/Human-HMDM-MTP-006_RNA_DMHCA_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-006_RNA_Des_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-006_RNA_GW_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-006_RNA_Mepip_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-006_RNA_T09_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-006_RNA_Vehicle_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-008_RNA_DMHCA_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-008_RNA_Des_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-008_RNA_GW_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-008_RNA_Mepip_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-008_RNA_T09_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-008_RNA_Vehicle_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-012_RNA_DMHCA_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-012_RNA_Des_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-012_RNA_GW_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-012_RNA_Mepip_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-012_RNA_T09_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-012_RNA_Vehicle_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-013_RNA_DMHCA_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-013_RNA_Des_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-013_RNA_GW_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-013_RNA_Mepip_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-013_RNA_T09_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-013_RNA_Vehicle_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-015_RNA_DMHCA_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-015_RNA_Des_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-015_RNA_GW_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-015_RNA_Mepip_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-015_RNA_T09_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-015_RNA_Vehicle_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-021_RNA_DMHCA_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-021_RNA_Des_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-021_RNA_GW_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-021_RNA_Mepip_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-021_RNA_T09_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-021_RNA_Vehicle_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-024_RNA_DMHCA_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-024_RNA_Des_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-024_RNA_GW_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-024_RNA_Mepip_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-024_RNA_T09_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-024_RNA_Vehicle_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-038_RNA_DMHCA_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-038_RNA_Des_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-038_RNA_GW_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-038_RNA_Mepip_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-038_RNA_T09_EDM_15-12-09
# 		./tag_directories/Human-HMDM-MTP-038_RNA_Vehicle_EDM_15-12-09
# 	Input file format: homerRmsk
# 	Filtering based on repeat parameters: kept 56082 of 56082
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-006_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-006_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-006_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-006_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-006_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-006_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-008_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-008_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-008_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-008_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-008_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-008_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-012_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-012_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-012_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-012_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-012_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-012_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-013_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-013_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-013_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-013_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-013_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-013_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-015_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-015_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-015_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-015_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-015_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-015_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-021_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-021_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-021_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-021_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-021_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-021_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-024_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-024_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-024_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-024_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-024_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-024_RNA_Vehicle_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-038_RNA_DMHCA_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-038_RNA_Des_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-038_RNA_GW_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-038_RNA_Mepip_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-038_RNA_T09_EDM_15-12-09
# 	Calculating read coverage for ./tag_directories/Human-HMDM-MTP-038_RNA_Vehicle_EDM_15-12-09
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 		Normalizing...
# 	Printing output
# 		Printed 26003 of 48436 repeats (expression >= -1e+20)

# %%
# read in RPKM values
rpkm_frame = pd.read_csv("rpkm.tsv",sep="\t")
columns = rpkm_frame.columns.values
columns[0] = "refseq"
for i in range(len(columns)):
    if "FPKM" in columns[i]:
        columns[i] = columns[i].split("/")[-1].split()[0]
rpkm_frame.columns = columns    
rpkm_frame['gene'] = [x.split("|")[0] for x in rpkm_frame['Annotation/Divergence']]
columns = list(rpkm_frame.columns.values)
columns = columns[:-1]
columns.insert(1,'gene')
rpkm_frame = rpkm_frame[columns]

# read in tag counts
reads_frame = pd.read_csv("normed.tsv",sep="\t")
columns = reads_frame.columns.values
columns[0] = "refseq"
for i in range(len(columns)):
    if "reads" in columns[i]:
        columns[i] = columns[i].split("/")[-1].split()[0]
reads_frame.columns = columns  
reads_frame['gene'] = [x.split("|")[0] for x in reads_frame['Annotation/Divergence']]
columns = list(reads_frame.columns.values)
columns = columns[:-1]
columns.insert(1,'gene')
reads_frame = reads_frame[columns]

raw_frame = pd.read_csv("raw.tsv",sep="\t")
columns = raw_frame.columns.values
columns[0] = "refseq"
for i in range(len(columns)):
    if "reads" in columns[i]:
        columns[i] = columns[i].split("/")[-1].split()[0]
raw_frame.columns = columns  
raw_frame['gene'] = [x.split("|")[0] for x in raw_frame['Annotation/Divergence']]
columns = list(raw_frame.columns.values)
columns = columns[:-1]
columns.insert(1,'gene')
raw_frame = raw_frame[columns]

refseq_gene_mapping = dict(zip(rpkm_frame['refseq'].values, [x.split("|")[0] for x in rpkm_frame['Annotation/Divergence']]))
gene_refseq_mapping = dict(zip([x.split("|")[0] for x in rpkm_frame['Annotation/Divergence']], rpkm_frame['refseq'].values))
refseq_gene_mapping.update(dict(zip(reads_frame['refseq'].values, [x.split("|")[0] for x in reads_frame['Annotation/Divergence']])))
gene_refseq_mapping.update(dict(zip([x.split("|")[0] for x in reads_frame['Annotation/Divergence']], reads_frame['refseq'].values)))
refseq_gene_mapping.update(dict(zip(raw_frame['refseq'].values, [x.split("|")[0] for x in raw_frame['Annotation/Divergence']])))
gene_refseq_mapping.update(dict(zip([x.split("|")[0] for x in raw_frame['Annotation/Divergence']], raw_frame['refseq'].values)))




# get filtered rpkm values
filtered_rpkm_frame =  rpkm_frame[[x for x in rpkm_frame.columns if x in filtered_summary_frame['originalName'].values]]
columns = [originalName_simpleName_dict[x] for x in filtered_rpkm_frame.columns.values]
filtered_rpkm_frame.columns = columns
filtered_rpkm_frame.index = rpkm_frame.refseq.values
# get rid of genes that aren't expressed at all
filtered_rpkm_frame = filtered_rpkm_frame[filtered_rpkm_frame.sum(axis=1) > 1.0]

filtered_reads_frame = reads_frame[[x for x in reads_frame.columns if x in filtered_summary_frame['originalName'].values]]
columns = [originalName_simpleName_dict[x] for x in filtered_reads_frame.columns.values]
filtered_reads_frame.columns =columns 
filtered_reads_frame.index = reads_frame.refseq.values


                                   
# create frame that's easier to use with factor plots
pivoting_frame = filtered_rpkm_frame.transpose()
_refseq = []
_gene = []
_rpkm = []
_simplifiedName = list(pivoting_frame.index.values) * pivoting_frame.shape[1]
_treatment = list(filtered_summary_frame['simpleTreatment'].values) * pivoting_frame.shape[1]
for refseq in pivoting_frame.columns:
    gene = refseq_gene_mapping[refseq]
    for rpkm in pivoting_frame[refseq].values:
        _rpkm.append(rpkm)
        _refseq.append(refseq)
        _gene.append(gene.upper())
filtered_rpkm_plottingFrame = pd.DataFrame({
'refseq': _refseq,
'gene': _gene, 
'rpkm': _rpkm,
'simplifiedName': _simplifiedName,
'treatment': _treatment
})
del pivoting_frame
        
filtered_rpkm_plottingFrame_log = filtered_rpkm_plottingFrame.copy()
filtered_rpkm_plottingFrame_log['rpkm'] = np.log2(filtered_rpkm_plottingFrame.rpkm)

pivoting_frame = filtered_reads_frame.transpose()
_refseq = []
_gene = []
_reads = []
_simplifiedName = list(pivoting_frame.index.values) * pivoting_frame.shape[1]
_treatment = list(filtered_summary_frame['simpleTreatment'].values) * pivoting_frame.shape[1]
for refseq in pivoting_frame.columns:
    gene = refseq_gene_mapping[refseq]
    for rpkm in pivoting_frame[refseq].values:
        _reads.append(rpkm)
        _refseq.append(refseq)
        _gene.append(gene.upper())
filtered_reads_plottingFrame = pd.DataFrame({
'refseq': _refseq,
'gene': _gene, 
'reads': _reads,
'simplifiedName': _simplifiedName,
'treatment': _treatment
})
del pivoting_frame

# %%
all_rpkm_frame = pd.read_csv("rpkm_all.tsv",sep="\t")
columns = all_rpkm_frame.columns.values
columns[0] = "refseq"
for i in range(len(columns)):
    if "FPKM" in columns[i]:
        columns[i] = columns[i].split("/")[-1].split()[0]
all_rpkm_frame.columns = columns    
all_rpkm_frame['gene'] = [x.split("|")[0] for x in all_rpkm_frame['Annotation/Divergence']]
columns = list(all_rpkm_frame.columns.values)
columns = columns[:-1]
columns.insert(1,'gene')
all_rpkm_frame = all_rpkm_frame[columns]
# all_rpkm_frame.columns = columns[:9] + ['_'.join(x.split('_')[0:3]).replace('Human-HMDM-','').replace('RNA_','') for x in columns[9:]]




### cluster samples according to correlation
samples = all_rpkm_frame.columns.values[9:]

labels = ['_'.join(x.split('_')[0:3]).replace('Human-HMDM-','').replace('RNA_','') for x in columns[9:]]

spearman_matrix = np.zeros((len(samples), len(samples)))
pearson_matrix = np.zeros((len(samples), len(samples)))
for i in range(len(samples)):
    spearman_matrix[i][i]=1.0
    pearson_matrix[i][i]=1.0

for i in range(len(samples) - 1):
    for j in range(i+1, len(samples)):
        values_1 = all_rpkm_frame[samples[i]].values
        values_2 = all_rpkm_frame[samples[j]].values
        pearson, pearson_pval = scipy.stats.pearsonr(values_1,values_2)
        spearman, spearman_pval = scipy.stats.spearmanr(values_1,values_2)
        pearson_matrix[i][j] = pearson
        pearson_matrix[j][i] = pearson
        
        spearman_matrix[i][j] = spearman
        spearman_matrix[j][i] = spearman
        
        

sns.set_context('notebook', font_scale=0.9)
cg = sns.clustermap(pearson_matrix, xticklabels=labels, yticklabels=labels)
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
plt.show()

cg = sns.clustermap(spearman_matrix, xticklabels=labels, yticklabels=labels)
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
plt.show()

sns.set_context('notebook', font_scale=1.0)

# %%
if not os.path.isdir('scatter_plots'):
    os.mkdir('scatter_plots')
treatments = sorted(list(set(summary_frame.index)))
for i in range(len(treatments)):
    for j in range(i, len(treatments)):
        print(treatments[i], treatments[j])
        columns = sorted(list(set(list(summary_frame.loc[treatments[i],'originalName']) + 
                              list(summary_frame.loc[treatments[j],'originalName']))))
        data = np.log2(all_rpkm_frame.loc[:,columns] + 1)
        data = data[data.sum(axis=1) > 0.0]
        data.columns = ['_'.join(x.split('_')[0:3]).replace('Human-HMDM-','').replace('RNA_','') for x in columns]
        cg = sns.pairplot(data, 
                          x_vars=[x for x in data.columns.values if treatments[i][1] in x],
                          y_vars=[x for x in data.columns.values if treatments[j][1] in x]
                         )
        
        plt.savefig('./scatter_plots/' + '_'.join(treatments[i] + treatments[j]) + '_logRpkm.png')
        plt.close()
# Out:
# ('Human', 'DMHCA') ('Human', 'DMHCA')
# ('Human', 'DMHCA') ('Human', 'Des')
# ('Human', 'DMHCA') ('Human', 'GW')
# ('Human', 'DMHCA') ('Human', 'Mepip')
# ('Human', 'DMHCA') ('Human', 'T09')
# ('Human', 'DMHCA') ('Human', 'Vehicle')
# ('Human', 'Des') ('Human', 'Des')
# ('Human', 'Des') ('Human', 'GW')
# ('Human', 'Des') ('Human', 'Mepip')
# ('Human', 'Des') ('Human', 'T09')
# ('Human', 'Des') ('Human', 'Vehicle')
# ('Human', 'GW') ('Human', 'GW')
# ('Human', 'GW') ('Human', 'Mepip')
# ('Human', 'GW') ('Human', 'T09')
# ('Human', 'GW') ('Human', 'Vehicle')
# ('Human', 'Mepip') ('Human', 'Mepip')
# ('Human', 'Mepip') ('Human', 'T09')
# ('Human', 'Mepip') ('Human', 'Vehicle')
# ('Human', 'T09') ('Human', 'T09')
# ('Human', 'T09') ('Human', 'Vehicle')
# ('Human', 'Vehicle') ('Human', 'Vehicle')
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/matplotlib/__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# ## Run IDR

# %%
# # %%capture
sampleColumns = rpkm_frame.columns.values[9:]
originalName_simpleTreatment_dict = dict(zip(filtered_summary_frame['originalName'], filtered_summary_frame['simpleTreatment']))
originalName_strain_dict = dict(zip(filtered_summary_frame['originalName'], filtered_summary_frame['strain']))

conditions = " ".join([originalName_strain_dict[x] + '_' + originalName_simpleTreatment_dict[x] for x in sampleColumns])
# !echo python /home/jenhan/code/seq_merge_pipe/run_idr_homerRNA.py rpkm.tsv $idrDirectory $conditions
# !python /home/jenhan/code/seq_merge_pipe/run_idr_homerRNA.py rpkm.tsv $idrDirectory $conditions
# Out:
# python /home/jenhan/code/seq_merge_pipe/run_idr_homerRNA.py rpkm.tsv /home/jenhan/analysis/MTP_analysis//idr/ Human_DMHCA Human_DMHCA Human_DMHCA Human_DMHCA Human_DMHCA Human_DMHCA Human_Des Human_Des Human_Des Human_Des Human_Des Human_Des Human_GW Human_GW Human_GW Human_GW Human_GW Human_GW Human_Mepip Human_Mepip Human_Mepip Human_Mepip Human_Mepip Human_Mepip Human_Mepip Human_T09 Human_T09 Human_T09 Human_T09 Human_T09 Human_T09 Human_T09 Human_T09 Human_Vehicle Human_Vehicle Human_Vehicle Human_Vehicle Human_Vehicle Human_Vehicle Human_Vehicle Human_Vehicle
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# Output files will be written to: /home/jenhan/analysis/MTP_analysis//idr/
# Using the following IDR threshold: 0.05
# Performing IDR analysis using the following columns and conditions:
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_DMHCA_EDM_15-12-09 reads FPKM 	 Human_DMHCA
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_DMHCA_EDM_15-12-09 reads FPKM 	 Human_DMHCA
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_DMHCA_EDM_15-12-09 reads FPKM 	 Human_DMHCA
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_DMHCA_EDM_15-12-09 reads FPKM 	 Human_DMHCA
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_DMHCA_EDM_15-12-09 reads FPKM 	 Human_DMHCA
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_DMHCA_EDM_15-12-09 reads FPKM 	 Human_DMHCA
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Des_EDM_15-12-09 reads FPKM 	 Human_Des
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_Des_EDM_15-12-09 reads FPKM 	 Human_Des
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Des_EDM_15-12-09 reads FPKM 	 Human_Des
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Des_EDM_15-12-09 reads FPKM 	 Human_Des
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Des_EDM_15-12-09 reads FPKM 	 Human_Des
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Des_EDM_15-12-09 reads FPKM 	 Human_Des
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_GW_EDM_15-12-09 reads FPKM 	 Human_GW
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_GW_EDM_15-12-09 reads FPKM 	 Human_GW
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_GW_EDM_15-12-09 reads FPKM 	 Human_GW
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_GW_EDM_15-12-09 reads FPKM 	 Human_GW
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_GW_EDM_15-12-09 reads FPKM 	 Human_GW
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_GW_EDM_15-12-09 reads FPKM 	 Human_GW
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Mepip_EDM_15-12-09 reads FPKM 	 Human_Mepip
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Mepip_EDM_15-12-09 reads FPKM 	 Human_Mepip
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_Mepip_EDM_15-12-09 reads FPKM 	 Human_Mepip
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_Mepip_EDM_15-12-09 reads FPKM 	 Human_Mepip
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Mepip_EDM_15-12-09 reads FPKM 	 Human_Mepip
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Mepip_EDM_15-12-09 reads FPKM 	 Human_Mepip
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Mepip_EDM_15-12-09 reads FPKM 	 Human_Mepip
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_T09_EDM_15-12-09 reads FPKM 	 Human_T09
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_T09_EDM_15-12-09 reads FPKM 	 Human_T09
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_T09_EDM_15-12-09 reads FPKM 	 Human_T09
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_T09_EDM_15-12-09 reads FPKM 	 Human_T09
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_T09_EDM_15-12-09 reads FPKM 	 Human_T09
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_T09_EDM_15-12-09 reads FPKM 	 Human_T09
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_T09_EDM_15-12-09 reads FPKM 	 Human_T09
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_T09_EDM_15-12-09 reads FPKM 	 Human_T09
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-021_RNA_Vehicle_EDM_15-12-09 reads FPKM 	 Human_Vehicle
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-012_RNA_Vehicle_EDM_15-12-09 reads FPKM 	 Human_Vehicle
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-038_RNA_Vehicle_EDM_15-12-09 reads FPKM 	 Human_Vehicle
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-013_RNA_Vehicle_EDM_15-12-09 reads FPKM 	 Human_Vehicle
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-006_RNA_Vehicle_EDM_15-12-09 reads FPKM 	 Human_Vehicle
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-024_RNA_Vehicle_EDM_15-12-09 reads FPKM 	 Human_Vehicle
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-015_RNA_Vehicle_EDM_15-12-09 reads FPKM 	 Human_Vehicle
# /home/jenhan/analysis/MTP_analysis//tag_directories/Human-HMDM-MTP-008_RNA_Vehicle_EDM_15-12-09 reads FPKM 	 Human_Vehicle
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.78 0.95 0.98 0.61]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16560/26003 (63.7%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16560/26003 (63.7%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.86 0.74 0.97 0.53]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14417/26003 (55.4%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14417/26003 (55.4%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.90 0.90 0.97 0.58]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15774/26003 (60.7%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15774/26003 (60.7%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.86 0.86 0.97 0.58]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15674/26003 (60.3%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15674/26003 (60.3%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.71 0.95 0.97 0.62]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16811/26003 (64.7%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16811/26003 (64.7%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.68 0.82 0.96 0.59]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16055/26003 (61.7%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16055/26003 (61.7%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.67 0.90 0.98 0.61]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16676/26003 (64.1%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16676/26003 (64.1%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.84 0.71 0.97 0.53]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14622/26003 (56.2%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14622/26003 (56.2%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.96 0.86 0.98 0.58]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15797/26003 (60.8%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15797/26003 (60.8%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.01 0.20 0.97 0.51]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 13960/26003 (53.7%)
#
# Number of peaks passing IDR cutoff of 0.05 - 13960/26003 (53.7%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.77 0.98 0.99 0.61]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16562/26003 (63.7%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16562/26003 (63.7%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.91 0.89 0.98 0.59]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16139/26003 (62.1%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16139/26003 (62.1%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.95 1.11 0.98 0.63]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 17020/26003 (65.5%)
#
# Number of peaks passing IDR cutoff of 0.05 - 17020/26003 (65.5%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.75 0.66 0.97 0.54]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14879/26003 (57.2%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14879/26003 (57.2%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.76 0.68 0.97 0.54]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14692/26003 (56.5%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14692/26003 (56.5%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.81 0.72 0.97 0.53]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14447/26003 (55.6%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14447/26003 (55.6%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.79 0.70 0.97 0.54]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14787/26003 (56.9%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14787/26003 (56.9%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.81 0.71 0.97 0.53]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14368/26003 (55.3%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14368/26003 (55.3%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.82 0.76 0.98 0.59]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16009/26003 (61.6%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16009/26003 (61.6%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.90 0.88 0.97 0.57]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15619/26003 (60.1%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15619/26003 (60.1%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.91 0.81 0.98 0.60]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16323/26003 (62.8%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16323/26003 (62.8%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [3.00 0.95 0.98 0.57]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15549/26003 (59.8%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15549/26003 (59.8%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.89 0.85 0.98 0.56]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15364/26003 (59.1%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15364/26003 (59.1%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.61 0.70 0.98 0.58]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15905/26003 (61.2%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15905/26003 (61.2%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.81 0.79 0.99 0.55]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15137/26003 (58.2%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15137/26003 (58.2%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.96 0.94 0.99 0.57]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15464/26003 (59.5%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15464/26003 (59.5%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.76 0.98 0.98 0.62]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16930/26003 (65.1%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16930/26003 (65.1%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.67 0.78 0.98 0.57]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15503/26003 (59.6%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15503/26003 (59.6%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.87 0.90 0.98 0.58]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15857/26003 (61.0%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15857/26003 (61.0%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.87 0.85 0.98 0.59]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16235/26003 (62.4%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16235/26003 (62.4%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.88 0.75 0.97 0.58]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15837/26003 (60.9%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15837/26003 (60.9%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.83 0.85 0.98 0.57]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15456/26003 (59.4%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15456/26003 (59.4%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.61 0.90 0.95 0.52]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 13818/26003 (53.1%)
#
# Number of peaks passing IDR cutoff of 0.05 - 13818/26003 (53.1%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.92 0.99 0.98 0.60]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16263/26003 (62.5%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16263/26003 (62.5%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.92 0.83 0.97 0.56]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15342/26003 (59.0%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15342/26003 (59.0%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.77 0.96 0.98 0.62]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16930/26003 (65.1%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16930/26003 (65.1%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.54 0.89 0.94 0.54]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14486/26003 (55.7%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14486/26003 (55.7%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.97 0.84 0.98 0.57]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15453/26003 (59.4%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15453/26003 (59.4%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.97 1.07 0.98 0.61]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16395/26003 (63.1%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16395/26003 (63.1%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.58 0.91 0.95 0.52]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 13872/26003 (53.3%)
#
# Number of peaks passing IDR cutoff of 0.05 - 13872/26003 (53.3%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [3.02 0.92 0.97 0.56]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15355/26003 (59.1%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15355/26003 (59.1%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.56 0.86 0.95 0.51]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 13767/26003 (52.9%)
#
# Number of peaks passing IDR cutoff of 0.05 - 13767/26003 (52.9%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.54 0.90 0.95 0.54]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14291/26003 (55.0%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14291/26003 (55.0%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.76 0.71 0.97 0.53]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14492/26003 (55.7%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14492/26003 (55.7%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [3.01 0.89 0.98 0.56]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15408/26003 (59.3%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15408/26003 (59.3%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.11 1.04 0.94 0.55]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 13192/26003 (50.7%)
#
# Number of peaks passing IDR cutoff of 0.05 - 13192/26003 (50.7%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.61 0.91 0.96 0.62]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16657/26003 (64.1%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16657/26003 (64.1%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.91 1.07 0.98 0.62]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16682/26003 (64.2%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16682/26003 (64.2%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.76 0.72 0.97 0.54]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14780/26003 (56.8%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14780/26003 (56.8%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.25 0.94 0.93 0.49]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 12450/26003 (47.9%)
#
# Number of peaks passing IDR cutoff of 0.05 - 12450/26003 (47.9%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.89 0.82 0.97 0.52]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14287/26003 (54.9%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14287/26003 (54.9%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.86 0.77 0.97 0.53]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14458/26003 (55.6%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14458/26003 (55.6%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.16 0.93 0.92 0.50]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 12453/26003 (47.9%)
#
# Number of peaks passing IDR cutoff of 0.05 - 12453/26003 (47.9%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.65 0.78 0.95 0.56]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15144/26003 (58.2%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15144/26003 (58.2%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.67 0.71 0.98 0.54]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14714/26003 (56.6%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14714/26003 (56.6%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.14 1.03 0.94 0.58]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14252/26003 (54.8%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14252/26003 (54.8%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.09 1.03 0.93 0.58]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 13992/26003 (53.8%)
#
# Number of peaks passing IDR cutoff of 0.05 - 13992/26003 (53.8%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.62 0.93 0.97 0.62]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16766/26003 (64.5%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16766/26003 (64.5%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.74 0.68 0.96 0.52]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14196/26003 (54.6%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14196/26003 (54.6%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.78 0.67 0.96 0.51]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14033/26003 (54.0%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14033/26003 (54.0%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.71 0.67 0.97 0.50]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 13731/26003 (52.8%)
#
# Number of peaks passing IDR cutoff of 0.05 - 13731/26003 (52.8%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.73 0.67 0.96 0.52]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14076/26003 (54.1%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14076/26003 (54.1%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [1.22 0.73 0.60 0.44]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 4610/26003 (17.7%)
#
# Number of peaks passing IDR cutoff of 0.05 - 4610/26003 (17.7%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.74 0.65 0.96 0.51]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14022/26003 (53.9%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14022/26003 (53.9%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.79 0.68 0.96 0.51]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 13834/26003 (53.2%)
#
# Number of peaks passing IDR cutoff of 0.05 - 13834/26003 (53.2%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.00 0.20 0.97 0.50]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 13701/26003 (52.7%)
#
# Number of peaks passing IDR cutoff of 0.05 - 13701/26003 (52.7%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.72 0.75 0.96 0.56]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15393/26003 (59.2%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15393/26003 (59.2%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.90 0.77 0.97 0.57]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15598/26003 (60.0%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15598/26003 (60.0%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [1.20 0.76 0.61 0.45]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 4766/26003 (18.3%)
#
# Number of peaks passing IDR cutoff of 0.05 - 4766/26003 (18.3%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.65 0.68 0.98 0.56]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15205/26003 (58.5%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15205/26003 (58.5%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.80 0.74 0.98 0.55]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14932/26003 (57.4%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14932/26003 (57.4%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.78 0.83 0.98 0.58]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15731/26003 (60.5%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15731/26003 (60.5%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.93 0.81 0.98 0.57]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15446/26003 (59.4%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15446/26003 (59.4%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [1.31 0.76 0.53 0.51]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 7279/26003 (28.0%)
#
# Number of peaks passing IDR cutoff of 0.05 - 7279/26003 (28.0%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.96 0.92 0.98 0.59]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16142/26003 (62.1%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16142/26003 (62.1%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.14 0.20 0.97 0.48]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 13208/26003 (50.8%)
#
# Number of peaks passing IDR cutoff of 0.05 - 13208/26003 (50.8%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.72 0.75 0.97 0.56]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15401/26003 (59.2%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15401/26003 (59.2%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [1.29 0.74 0.54 0.50]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 6828/26003 (26.3%)
#
# Number of peaks passing IDR cutoff of 0.05 - 6828/26003 (26.3%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.80 0.82 0.97 0.57]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15649/26003 (60.2%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15649/26003 (60.2%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.73 0.82 0.98 0.57]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15532/26003 (59.7%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15532/26003 (59.7%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [1.21 0.74 0.59 0.46]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 4941/26003 (19.0%)
#
# Number of peaks passing IDR cutoff of 0.05 - 4941/26003 (19.0%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.82 0.76 0.98 0.58]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15753/26003 (60.6%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15753/26003 (60.6%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.96 0.88 0.98 0.57]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15449/26003 (59.4%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15449/26003 (59.4%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [1.21 0.75 0.59 0.46]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 5130/26003 (19.7%)
#
# Number of peaks passing IDR cutoff of 0.05 - 5130/26003 (19.7%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [1.38 0.76 0.48 0.54]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 8958/26003 (34.4%)
#
# Number of peaks passing IDR cutoff of 0.05 - 8958/26003 (34.4%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.01 0.20 0.98 0.49]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 13459/26003 (51.8%)
#
# Number of peaks passing IDR cutoff of 0.05 - 13459/26003 (51.8%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.75 1.13 0.98 0.57]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15075/26003 (58.0%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15075/26003 (58.0%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [3.00 1.02 0.98 0.59]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16056/26003 (61.7%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16056/26003 (61.7%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.07 0.20 0.97 0.50]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 13556/26003 (52.1%)
#
# Number of peaks passing IDR cutoff of 0.05 - 13556/26003 (52.1%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.75 0.76 0.97 0.55]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14946/26003 (57.5%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14946/26003 (57.5%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.91 0.82 0.98 0.55]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15099/26003 (58.1%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15099/26003 (58.1%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [3.04 1.05 0.97 0.55]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14792/26003 (56.9%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14792/26003 (56.9%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [3.01 0.98 0.97 0.54]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14530/26003 (55.9%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14530/26003 (55.9%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.81 0.80 0.95 0.52]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14039/26003 (54.0%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14039/26003 (54.0%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.87 0.80 0.97 0.52]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14074/26003 (54.1%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14074/26003 (54.1%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.88 0.87 0.99 0.59]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16080/26003 (61.8%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16080/26003 (61.8%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.82 0.80 0.97 0.55]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15079/26003 (58.0%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15079/26003 (58.0%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.84 0.74 0.97 0.57]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15481/26003 (59.5%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15481/26003 (59.5%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.76 0.79 0.97 0.56]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15339/26003 (59.0%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15339/26003 (59.0%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.88 0.79 0.97 0.57]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15572/26003 (59.9%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15572/26003 (59.9%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.82 0.83 0.98 0.55]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15041/26003 (57.8%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15041/26003 (57.8%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.81 1.06 0.97 0.56]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14841/26003 (57.1%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14841/26003 (57.1%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.81 0.98 0.97 0.57]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15296/26003 (58.8%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15296/26003 (58.8%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.89 0.73 0.97 0.52]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14165/26003 (54.5%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14165/26003 (54.5%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.96 1.11 0.97 0.58]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15725/26003 (60.5%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15725/26003 (60.5%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [3.02 1.17 0.98 0.58]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15586/26003 (59.9%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15586/26003 (59.9%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.89 0.89 0.97 0.56]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15299/26003 (58.8%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15299/26003 (58.8%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.51 0.81 0.96 0.58]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15721/26003 (60.5%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15721/26003 (60.5%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.79 0.76 0.96 0.51]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 13942/26003 (53.6%)
#
# Number of peaks passing IDR cutoff of 0.05 - 13942/26003 (53.6%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.66 0.93 0.97 0.58]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15525/26003 (59.7%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15525/26003 (59.7%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.63 0.87 0.97 0.58]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15643/26003 (60.2%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15643/26003 (60.2%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.68 0.87 0.96 0.55]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15015/26003 (57.7%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15015/26003 (57.7%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.81 0.74 0.96 0.52]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14132/26003 (54.3%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14132/26003 (54.3%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.73 0.89 0.97 0.59]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16147/26003 (62.1%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16147/26003 (62.1%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.76 0.89 0.98 0.59]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16052/26003 (61.7%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16052/26003 (61.7%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.79 0.86 0.97 0.57]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15596/26003 (60.0%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15596/26003 (60.0%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.89 0.76 0.96 0.53]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14382/26003 (55.3%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14382/26003 (55.3%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.88 0.73 0.97 0.52]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14169/26003 (54.5%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14169/26003 (54.5%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.85 0.73 0.96 0.53]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 14571/26003 (56.0%)
#
# Number of peaks passing IDR cutoff of 0.05 - 14571/26003 (56.0%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.98 1.06 0.98 0.61]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 16583/26003 (63.8%)
#
# Number of peaks passing IDR cutoff of 0.05 - 16583/26003 (63.8%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.96 0.91 0.98 0.58]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15891/26003 (61.1%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15891/26003 (61.1%)
#
# Initial parameter values: [0.10 1.00 0.20 0.50]
# Final parameter values: [2.94 0.86 0.98 0.56]
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/idr-2.0.2-py3.4-linux-x86_64.egg/idr/idr.py:415: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if localIDRs == None or IDRs == None:
# Number of reported peaks - 15290/26003 (58.8%)
#
# Number of peaks passing IDR cutoff of 0.05 - 15290/26003 (58.8%)

# %%
idr_rpkm_frame = pd.read_csv('idr/idr_union_rpkm.tsv', sep='\t')

columns = idr_rpkm_frame.columns.values
columns[0] = "refseq"
for i in range(len(columns)):
    if "FPKM" in columns[i]:
        columns[i] = originalName_simpleName_dict[columns[i].split("/")[-1].split()[0]]
idr_rpkm_frame.columns = columns    
idr_rpkm_frame['gene'] = [x.split("|")[0].upper() for x in idr_rpkm_frame['Annotation/Divergence']]
columns = list(idr_rpkm_frame.columns.values)
columns = columns[:-1]
columns.insert(1,'gene')
idr_rpkm_frame = idr_rpkm_frame[columns]
idr_rpkm_frame.index = idr_rpkm_frame['gene'].values
idr_rpkm_frame = idr_rpkm_frame.ix[:,9:]

# %%
data = idr_rpkm_mean_frame[idr_rpkm_mean_frame.index.isin(genes)]

# %%
np.log2(data.div(data['Vehicle'].values,axis=0))
# Out:
#         Vehicle       Des     DMHCA     Mepip        GW       T09
# ABCA1         0  3.201836  3.919455  4.670107  4.404651  4.804420
# ABCG1         0  6.052442  7.081521  8.368672  7.721666  8.058832
# DHCR24        0 -1.691312 -1.793466 -3.020427 -0.608252 -0.241898
# FASN          0 -1.606633 -0.678764 -1.799000  1.929729  2.148656
# HMGCR         0 -2.819544 -2.567976 -3.927892 -0.787657 -0.481833
# LDLR          0 -3.325746 -1.818809 -3.786938  0.147919  0.414362
# SREBF1        0  1.464676  2.479821  2.353744  3.471914  3.774985

# %%
data
# Out:
#            Vehicle        Des      DMHCA      Mepip          GW         T09
# ABCA1     2.875250  26.456000  43.506000  73.201143   60.898667   80.343375
# ABCG1     0.249875  16.584000  33.843333  82.593143   52.744333   66.630500
# DHCR24  128.273125  39.719167  37.004000  15.808714   84.146000  108.471875
# FASN     34.585125  11.356500  21.605333   9.938857  131.763667  153.355500
# HMGCR    55.239750   7.825000   9.315667   3.629429   31.999500   39.555375
# LDLR     31.625250   3.154167   8.964333   2.291143   35.039833   42.147250
# SREBF1    7.218500  19.923167  40.266833  36.897286   80.093500   98.816750

# %%
idr_rpkm_mean_frame = pd.DataFrame()
treatment_col_dict = {}
for col in idr_rpkm_frame.columns.values:
    treatment = col.split('_')[1]
    if not treatment in treatment_col_dict:
        treatment_col_dict[treatment] = [col]
    else:
        treatment_col_dict[treatment].append(col)
for treatment in treatment_col_dict:
    idr_rpkm_mean_frame[treatment] = np.mean(idr_rpkm_frame[treatment_col_dict[treatment]], axis=1)
idr_rpkm_mean_frame = idr_rpkm_mean_frame[['Vehicle', 'Des', 'DMHCA', 'Mepip', 'GW', 'T09']] 
idr_rpkm_mean_frame = idr_rpkm_mean_frame.sort()
genes = [x.upper() for x in ['Abca1',
'Abcg1',
'srebf1',
'LDLR',
'Dhcr24',
'Hmgcr',
'Fasn'
]]
plt.figure(figsize=(2,2))
fold_frame = idr_rpkm_mean_frame[idr_rpkm_mean_frame.index.isin(genes)]
fold_frame = fold_frame.div(fold_frame['Vehicle'].values,axis=0)
fold_frame.drop('Vehicle', axis=1, inplace=True)
fold_frame = np.log2(fold_frame)
with sns.axes_style('whitegrid'):
    cg = sns.heatmap(fold_frame, cmap='coolwarm',vmax=6)
    plt.savefig('gene_heatmap.pdf', bbox_inches='tight')

# %% [markdown]
# ## Calcuate Differential Expression with EdgeR

# %%
# # %%capture
# use Homer to call differentially expressed genes with replicates
sample_condition_dict = dict(zip(filtered_summary_frame['originalName'], filtered_summary_frame['simpleTreatment']))
samples = raw_frame.columns[9:].values

conditions = " ".join([sample_condition_dict[x] for x in samples])
! getDiffExpression.pl raw.tsv $conditions > homer_diffExpresion.tsv
# Out:
# 	Autodetecting input file format...
# 	Using edgeR to calculate differential expression/enrichment...
# 	Autodetected analyzeRepeats.pl file
# Loading required package: limma
# Loading required package: limma
# Loading required package: limma
# Loading required package: limma
# Loading required package: limma
# Loading required package: limma
# Loading required package: limma
# Loading required package: limma
# Loading required package: limma
# Loading required package: limma
# Loading required package: limma
# Loading required package: limma
# Loading required package: limma
# Loading required package: limma
# Loading required package: limma

# %%
diffExpression_frame = pd.read_csv('homer_diffExpresion.tsv', sep='\t')
columns = diffExpression_frame.columns.values
columns[0]='refseq'
columns = [x.split('/')[-1] if '/' in x else x for x in columns]
diffExpression_frame.columns=columns
diffExpression_frame.index = diffExpression_frame.refseq.values
diffExpression_frame['gene'] = [x.split('|')[0] for x in diffExpression_frame['Divergence']]
columns = ['refseq', 'gene'] + [x for x in diffExpression_frame.columns if 'vs.' in x]
diffExpression_frame = diffExpression_frame[columns]

# %%
treatment_up_dict = {}
treatment_down_dict = {}

if not os.path.isdir('gene_ontology'):
    os.mkdir('gene_ontology')
    
fdr_threshold = 0.05

fdrColumns = [x for x in diffExpression_frame.columns if 'FDR' in x]


for c in fdrColumns:
    if 'Vehicle' in c:
        tokens = c.split()
        treatment1 = tokens[0]
        treatment2 = tokens[2]
        
        fc_column = c.replace('FDR', 'logFC')
        
        current_frame = diffExpression_frame[diffExpression_frame[c] < fdr_threshold][[c, fc_column, 'gene']]
        
        if treatment1 == 'VEH':
            up_genes = current_frame[current_frame[fc_column] > 0.0]['gene'].values
            down_genes = current_frame[current_frame[fc_column] < 0.0]['gene'].values
            treatment = treatment2
        else:
            treatment = treatment1
            down_genes = current_frame[current_frame[fc_column] > 0.0]['gene'].values
            up_genes = current_frame[current_frame[fc_column] < 0.0]['gene'].values
        
        treatment_up_dict[treatment] = up_genes
        treatment_down_dict[treatment] = down_genes
        
        # wrtite genes for gene ontology
        up_file = open('./gene_ontology/' + treatment + '_up.txt', 'w')
        for g in up_genes:
            up_file.write(g.upper() + '\n')
        up_file.close()
        
        down_file = open('./gene_ontology/' + treatment + '_down.txt', 'w')
        for g in down_genes:
            down_file.write(g.upper() + '\n')
        print(treatment, len(up_genes), len(down_genes))
        down_file.close()
# Out:
# DMHCA 47 53
# Des 27 69
# GW 189 22
# Mepip 562 398
# T09 383 935

# %%
if not os.path.isdir('./diffExpressed_vennDiagrams'):
    os.mkdir('./diffExpressed_vennDiagrams')
    
# get up and down regulated genes versus vehicle for each condition
# create heat map visualization for how many differentially expressed genes are shared
treatments = sorted(treatment_up_dict.keys())

treatments_up = [x[0] for x in sorted(tuple(zip(treatments, 
                                                [len(treatment_up_dict[x]) for x in treatments])), 
                                      key=lambda x: x[1])]
treatments_down = [x[0] for x in sorted(tuple(zip(treatments, 
                                                [len(treatment_down_dict[x]) for x in treatments])), 
                                      key=lambda x: x[1])]

treatment_up_index_dict = dict(zip(treatments_up , range(len(treatments))))

treatment_down_index_dict = dict(zip(treatments_down , range(len(treatments))))
  
up_matrix = np.zeros((len(treatments), len(treatments)))
down_matrix = np.zeros((len(treatments), len(treatments)))

for i in range(len(treatments) - 1):
    for j in range(i+1, len(treatments)):
        treatment1 = treatments[i]
        treatment2 = treatments[j]
        
        ind1_up = treatment_up_index_dict[treatment1]
        ind2_up = treatment_up_index_dict[treatment2]
        ind1_down = treatment_down_index_dict[treatment1]
        ind2_down =treatment_down_index_dict[treatment2]
        
        num_intersecting_up = len(set(treatment_up_dict[treatment1]).intersection(set(treatment_up_dict[treatment2])))
        num_intersecting_down = len(set(treatment_down_dict[treatment1]).intersection(set(treatment_down_dict[treatment2])))
        up_matrix[ind1_up][ind2_up] = num_intersecting_up
        up_matrix[ind2_up][ind1_up] = num_intersecting_up
        down_matrix[ind1_down][ind2_down] = num_intersecting_down
        down_matrix[ind2_down][ind1_down] = num_intersecting_down

# fill in diagonals
for i in range(len(treatments)):
        treatment = treatments[i]
        ind_up = treatment_up_index_dict[treatment]
        ind_down = treatment_down_index_dict[treatment]
        num_up = len(set(treatment_up_dict[treatment]))
        num_down = len(set(treatment_down_dict[treatment]))
        up_matrix[ind_up][ind_up] = num_up
        down_matrix[ind_down][ind_down] = num_down


up_labels = [x + ' (' +str(len(treatment_up_dict[x])) + ')' for x in treatments_up]
down_labels = [x + ' (' +str(len(treatment_down_dict[x])) + ')' for x in treatments_down]


# convert matrices to data frames
up_frame = pd.DataFrame(up_matrix).astype(int)
up_frame.columns = up_labels
up_frame.index = up_labels

down_frame = pd.DataFrame(down_matrix).astype(int)
down_frame.columns = down_labels
down_frame.index = down_labels

up_frame = up_frame.div(up_frame.max(axis=1), axis=0)
down_frame = down_frame.div(down_frame.max(axis=1), axis=0)

sns.heatmap(up_frame, annot=True)
plt.title("Shared Up-Regulated Genes")
plt.savefig('diffExpressed_vennDiagrams/diffExpressed_matrix_up.png')
plt.show()

sns.heatmap(down_frame, annot=True)
plt.title("Shared Down-Regulated Genes")
plt.savefig('diffExpressed_vennDiagrams/diffExpressed_matrix_down.png')
plt.show()

# %%
### make Venn Diagrams
if not os.path.isdir('./diffExpressed_vennDiagrams'):
    os.mkdir('./diffExpressed_vennDiagrams')
treatments = sorted(treatment_up_dict.keys())

for i in range(len(treatments) - 1):
    for j in range(i+1, len(treatments)):
        treatment1 = treatments[i]
        treatment2 = treatments[j]

        up_1 = set(treatment_up_dict[treatment1])
        up_2 = set(treatment_up_dict[treatment2])
        
        down_1 = set(treatment_down_dict[treatment1])
        down_2 = set(treatment_down_dict[treatment2])
        
        venn2([up_1, up_2], set_labels=[treatment1, treatment2])
        plt.savefig('./diffExpressed_vennDiagrams/' + treatment1 + '_' + treatment2 + '_up_vs_veh_venn.png')
        plt.close()
        
        venn2([down_1, down_2], set_labels=[treatment1, treatment2])
        plt.savefig('./diffExpressed_vennDiagrams/' + treatment1 + '_' + treatment2 + '_down_vs_veh_venn.png')
        plt.close()
# Out:
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/matplotlib_venn-0.9-py3.4.egg/matplotlib_venn/_venn3.py:422: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %% [markdown]
# ## Gene Ontology Enrichment

# %%
outFile = open('./gene_ontology/background.txt', 'w')
for g in raw_frame[raw_frame.ix[:,9:].sum(axis=1) > 16.0]['gene'].values:
    outFile.write(g.upper() + '\n')
outFile.close()

for f in os.listdir('./gene_ontology/'):
    if not 'background' in f and not 'result' in f:
        out_name = f.replace('.txt', '_result.txt')
#         os.system('/bioinformatics/software/anaconda2.7/bin/python2 /home/jenhan/code/go_enrichment_scripts/find_enrichment.py ./gene_ontology/' 
#                   + f +' ./gene_ontology/background.txt human_association --pval=0.05 > ./gene_ontology/' + out_name)
        print('/bioinformatics/software/anaconda2.7/bin/python2 /home/jenhan/code/go_enrichment_scripts/find_enrichment.py ./gene_ontology/' 
                  + f +' ./gene_ontology/background.txt human_association --pval=0.05 > ./gene_ontology/' + out_name + ' &')
# Out:
# /bioinformatics/software/anaconda2.7/bin/python2 /home/jenhan/code/go_enrichment_scripts/find_enrichment.py ./gene_ontology/Mepip_up.txt ./gene_ontology/background.txt human_association --pval=0.05 > ./gene_ontology/Mepip_up_result.txt &
# /bioinformatics/software/anaconda2.7/bin/python2 /home/jenhan/code/go_enrichment_scripts/find_enrichment.py ./gene_ontology/DMHCA_up.txt ./gene_ontology/background.txt human_association --pval=0.05 > ./gene_ontology/DMHCA_up_result.txt &
# /bioinformatics/software/anaconda2.7/bin/python2 /home/jenhan/code/go_enrichment_scripts/find_enrichment.py ./gene_ontology/T09_down.txt ./gene_ontology/background.txt human_association --pval=0.05 > ./gene_ontology/T09_down_result.txt &
# /bioinformatics/software/anaconda2.7/bin/python2 /home/jenhan/code/go_enrichment_scripts/find_enrichment.py ./gene_ontology/T09_up.txt ./gene_ontology/background.txt human_association --pval=0.05 > ./gene_ontology/T09_up_result.txt &
# /bioinformatics/software/anaconda2.7/bin/python2 /home/jenhan/code/go_enrichment_scripts/find_enrichment.py ./gene_ontology/DMHCA_down.txt ./gene_ontology/background.txt human_association --pval=0.05 > ./gene_ontology/DMHCA_down_result.txt &
# /bioinformatics/software/anaconda2.7/bin/python2 /home/jenhan/code/go_enrichment_scripts/find_enrichment.py ./gene_ontology/GW_down.txt ./gene_ontology/background.txt human_association --pval=0.05 > ./gene_ontology/GW_down_result.txt &
# /bioinformatics/software/anaconda2.7/bin/python2 /home/jenhan/code/go_enrichment_scripts/find_enrichment.py ./gene_ontology/._significant_terms_down.png ./gene_ontology/background.txt human_association --pval=0.05 > ./gene_ontology/._significant_terms_down.png &
# /bioinformatics/software/anaconda2.7/bin/python2 /home/jenhan/code/go_enrichment_scripts/find_enrichment.py ./gene_ontology/._significant_terms_down.pdf ./gene_ontology/background.txt human_association --pval=0.05 > ./gene_ontology/._significant_terms_down.pdf &
# /bioinformatics/software/anaconda2.7/bin/python2 /home/jenhan/code/go_enrichment_scripts/find_enrichment.py ./gene_ontology/Mepip_down.txt ./gene_ontology/background.txt human_association --pval=0.05 > ./gene_ontology/Mepip_down_result.txt &
# /bioinformatics/software/anaconda2.7/bin/python2 /home/jenhan/code/go_enrichment_scripts/find_enrichment.py ./gene_ontology/Des_up.txt ./gene_ontology/background.txt human_association --pval=0.05 > ./gene_ontology/Des_up_result.txt &
# /bioinformatics/software/anaconda2.7/bin/python2 /home/jenhan/code/go_enrichment_scripts/find_enrichment.py ./gene_ontology/GW_up.txt ./gene_ontology/background.txt human_association --pval=0.05 > ./gene_ontology/GW_up_result.txt &
# /bioinformatics/software/anaconda2.7/bin/python2 /home/jenhan/code/go_enrichment_scripts/find_enrichment.py ./gene_ontology/Des_down.txt ./gene_ontology/background.txt human_association --pval=0.05 > ./gene_ontology/Des_down_result.txt &
# /bioinformatics/software/anaconda2.7/bin/python2 /home/jenhan/code/go_enrichment_scripts/find_enrichment.py ./gene_ontology/._significant_terms_up.png ./gene_ontology/background.txt human_association --pval=0.05 > ./gene_ontology/._significant_terms_up.png &
# /bioinformatics/software/anaconda2.7/bin/python2 /home/jenhan/code/go_enrichment_scripts/find_enrichment.py ./gene_ontology/._significant_terms_up.pdf ./gene_ontology/background.txt human_association --pval=0.05 > ./gene_ontology/._significant_terms_up.pdf &

# %%
fdr_threshold = 0.05
p_threshold = 0.05
term_tuples = []
terms = []
treatments = []
for f in os.listdir('./gene_ontology/'):
#     if 'result' in f and 'up' in f and not 'mepip' in f.lower():
    if 'result' in f and 'up' in f :
        with open('./gene_ontology/' + f) as data:
            data = data.readlines()
        if len(data):
            results = pd.read_csv('./gene_ontology/' + f ,sep='\t', skiprows=2)
            treatment = f.split('_')[0]
            treatments.append(treatment)
            significant_results = results[results['p_bonferroni'] < p_threshold]

            # seperate enriched and purified results
            enriched_results = significant_results[significant_results['enrichment']=='e']

            purified_results= significant_results[significant_results['enrichment']=='p']
            terms = terms + list(enriched_results['description'].values)
            term_tuples = term_tuples +list(zip(enriched_results['id'].values,
                                                enriched_results['description'].values, 
                                                enriched_results['p_bonferroni'].values, 
                                                [treatment] * significant_results.shape[0]))
            print(treatment, enriched_results.shape)


terms = sorted(list(set(terms)))
treatments=sorted(treatments)
# treatments.remove('1um-Mepip')
term_id_dict = dict(zip([x[1] for x in term_tuples],
                       [x[0] for x in term_tuples]))
term_index_dict = dict(zip(terms, range(len(terms))))

treatment_index_dict = dict(zip(treatments, range(len(treatments))))
counter = 0
matrix = np.ones((len(terms), len(treatments)))
for t in term_tuples:
    matrix[term_index_dict[t[1]]][treatment_index_dict[t[3]]] = t[2]
up_frame = pd.DataFrame(matrix, columns=treatments, index=terms)
up_frame['id'] = [term_id_dict[x] for x in up_frame.index.values]
# cg = sns.clustermap(-1* np.log10(up_frame.ix[:,:-1] + 0.0000001),
#                    col_cluster=False)
# plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation=0);


# hm = cg.ax_heatmap.get_position()
# plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), fontsize=5, rotation=0)
# plt.setp(cg.ax_heatmap.xaxis.get_majorticklabels(), fontsize=10, rotation=90)


# # cg.ax_heatmap.set_position([hm.x0, hm.y0, hm.width*0.5, hm.height*2.25])
# # col = cg.ax_row_dendrogram.get_position()
# # cg.ax_row_dendrogram.set_position([col.x0, col.y0, col.width, col.height*2.25])
# plt.savefig('./gene_ontology/significant_terms_up.pdf', bbox_inches='tight')
# sns.set_context('notebook', font_scale=1)
# plt.title('Up-Regulated GO Terms')
# plt.show()

term_tuples = []
terms = []
treatments = []
for f in os.listdir('./gene_ontology/'):
#     if 'result' in f and 'down' in f and not 'mepip' in f.lower():
    if 'result' in f and 'down' in f:
        with open('./gene_ontology/' + f) as data:
            data = data.readlines()
        if len(data):
            results = pd.read_csv('./gene_ontology/' + f ,sep='\t', skiprows=2)
            treatment = f.split('_')[0]
            treatments.append(treatment)
            significant_results = results[results['p_bonferroni'] < p_threshold]

            # seperate enriched and purified results
            enriched_results = significant_results[significant_results['enrichment']=='e']

            purified_results= significant_results[significant_results['enrichment']=='p']
            terms = terms + list(enriched_results['description'].values)
            term_tuples = term_tuples +list(zip(enriched_results['id'].values,
                                                enriched_results['description'].values, 
                                                enriched_results['p_bonferroni'].values, 
                                                [treatment] * significant_results.shape[0]))
            print(treatment, enriched_results.shape)


terms = sorted(list(set(terms)))
treatments=sorted(treatments)
# treatments.remove('1um-Mepip')
term_id_dict = dict(zip([x[1] for x in term_tuples],
                       [x[0] for x in term_tuples]))
term_index_dict = dict(zip(terms, range(len(terms))))

treatment_index_dict = dict(zip(treatments, range(len(treatments))))
counter = 0
matrix = np.ones((len(terms), len(treatments)))
for t in term_tuples:
    matrix[term_index_dict[t[1]]][treatment_index_dict[t[3]]] = t[2]
down_frame = pd.DataFrame(matrix, columns=treatments, index=terms)
down_frame['id'] = [term_id_dict[x] for x in down_frame.index.values]

# cg = sns.clustermap(-1* np.log10(down_frame.ix[:,:-1] + 0.0000001),
#                    col_cluster=False)
# plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation=0);


# hm = cg.ax_heatmap.get_position()
# plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), fontsize=5, rotation=0)
# plt.setp(cg.ax_heatmap.xaxis.get_majorticklabels(), fontsize=10, rotation=90)


# cg.ax_heatmap.set_position([hm.x0, hm.y0, hm.width*0.5, hm.height*2.25])
# col = cg.ax_row_dendrogram.get_position()
# cg.ax_row_dendrogram.set_position([col.x0, col.y0, col.width, col.height*2.25])
# plt.savefig('./gene_ontology/significant_terms_down.pdf', bbox_inches='tight')
# sns.set_context('notebook', font_scale=1)
# plt.title('Down-regulated GO Terms')
# plt.show()




# save to text and spreadsheets
# labels = up_frame.index.values
# features = up_frame.ix[:,0:5]
# distances = scipy.spatial.distance.pdist(features)
# linkage = scipy.cluster.hierarchy.linkage(distances, method='complete')
# dendrogram = scipy.cluster.hierarchy.dendrogram(linkage, labels = labels);
# plt.close()
# up_frame = up_frame.ix[dendrogram['ivl'],:]
# labels = down_frame.index.values
# features = down_frame.ix[:,0:5]
# distances = scipy.spatial.distance.pdist(features)
# linkage = scipy.cluster.hierarchy.linkage(distances, method='complete')
# dendrogram = scipy.cluster.hierarchy.dendrogram(linkage, labels = labels);
# plt.close()
# down_frame = down_frame.ix[dendrogram['ivl'],:]

up_frame=up_frame[[x for x in  up_frame.columns if not '30' in x]]
down_frame=down_frame[[x for x in  down_frame.columns if not '30' in x]]

# save go terms
up_frame.to_csv('go_terms_up.tsv', sep='\t')
down_frame.to_csv('go_terms_down.tsv', sep='\t')
out_file = open('go_ids_up.txt', 'w')
for id in up_frame['id'].values:
    out_file.write(id.strip() + '\n')
out_file.close()

out_file = open('go_ids_down.txt', 'w')
for id in down_frame['id'].values:
    out_file.write(id.strip() + '\n')
out_file.close()
# Out:
# Mepip (269, 10)
# DMHCA (27, 10)
# T09 (155, 10)
# Des (11, 10)
# GW (93, 10)
# T09 (50, 10)
# Mepip (38, 10)
# Des (61, 10)
# GW (0, 10)
# DMHCA (42, 10)

# %%
for t in ['membrane',
                'lipid biosynthetic process',
                'triglyceride metabolic process',
                'response to unfolded protein']:
    if not t in up_frame.index.values:
        up_frame = up_frame.T
        up_frame[t]= 1.0
        up_frame = up_frame.T
    

data = pd.DataFrame(up_frame.ix[['membrane',
                'lipid biosynthetic process',
                'triglyceride metabolic process',
                'response to unfolded protein'],
                   ['Des',
                    'DMHCA',
                    'Mepip', 
                    'GW', 
                    'T09']])
data = data.fillna(1)
plt.figure(figsize=(2,1.5))
with sns.axes_style('whitegrid'):
    sns.heatmap(-1*np.log10(data.astype(float)), 
                cmap='Reds',
                square=True,
               vmax=5)
plt.savefig('./gene_ontology/significant_terms_up.pdf', bbox_inches='tight')
plt.show()

for t in ['cholesterol metabolic process',
                'sterol biosynthetic process',
                       ]:
    if not t in down_frame.index.values:
        down_frame = down_frame.T
        down_frame[t]= 1.0
        down_frame = down_frame.T
        
        
data = down_frame.ix[['cholesterol metabolic process',
                'sterol biosynthetic process',
                       ],
                     ['Des',
                    'DMHCA',
                    'Mepip', 
                    'GW', 
                    'T09']]
data = data.fillna(1)

plt.figure(figsize=(2,1.5))
with sns.axes_style('whitegrid'):
    sns.heatmap(-1*np.log10(data.astype(float)), 
                cmap='Blues',
                square=True,
               vmax=5)
plt.savefig('./gene_ontology/significant_terms_down.pdf', bbox_inches='tight')

# %% [markdown]
# ## Bar Plots

# %%
! rm ./bar_plots/*
treatments = ['Vehicle', 
                'Des',
                'DMHCA',
                'Mepip',
                'GW',
                'T09'
                ]
p_threshold = 0.05
sns.set_context('paper')
if not os.path.isdir('bar_plots'):
    os.mkdir('bar_plots')
target_genes = ['Abca1',
'Abcg1',
'srebf1',
'LDLR',
'Dhcr24',
'Hmgcr',
'Fasn'
]
for g in target_genes:
    data = filtered_rpkm_plottingFrame[filtered_rpkm_plottingFrame['gene'] == g.upper()]
    if data.shape[0] > 0:
        sns.factorplot( y='rpkm', 
                        x='treatment',
                        kind='bar',
                        data=data,
                        order = treatments,
                        color='grey',
                        ci=68, size=10
                         )
        plt.xticks(rotation=90)
        # generate p-values vs vehicle
        for i in range(1, len(treatments)):
            treatment_vals = list(data[data['treatment']==treatments[i]]['rpkm'].values)
            vehicle_vals = list(data[data['treatment']== treatments[0]]['rpkm'].values)
            stat, p = scipy.stats.ttest_ind(treatment_vals,
                                           vehicle_vals) 
            ax = plt.gca()
            height = int(np.max(data['rpkm'].values))
            if p < p_threshold:                
                ax.annotate("{:.3f}".format(p).replace('0.000','<0.001'),
                            xy=(i - 0.25,0.8* max(treatment_vals) + 0.01 *height),
                           fontsize=10)
        if g.upper() in ['DHCR24', 'HMGCR', 'FASN']:
            # generate p values for GW and T vs  desmosterol, dMHCA and PePIP treatments
            stat, p = scipy.stats.ttest_ind(data[
                    data['treatment'].isin(['10um-Des','30um-Des', '1um-DMHCA','1um-Mepip'])]['rpkm'],
                    data[data['treatment'].isin(['1um-GW','1um-T090'])]['rpkm'],
                                           )
            if p < p_threshold: 
                current_height = height + 0.01 * height
                ax.arrow(1, current_height, 0, -0.02*height, linewidth=1.0,head_width=0.0) #left line
                ax.arrow(3, current_height, 0, -0.02*height, linewidth=1.0,head_width=0.0) # right line
                ax.arrow(1, current_height, 2 ,0, linewidth=1.0,head_width=0.0) # horizontal line
                
                ax.arrow(4, current_height, 0, -0.02*height, linewidth=1.0,head_width=0.0) #left line
                ax.arrow(5, current_height, 0, -0.02*height, linewidth=1.0,head_width=0.0) # right line
                ax.arrow(4, current_height, 1 ,0, linewidth=1.0,head_width=0.0) # horizontal line
                
                ax.arrow(2.5, current_height, 0, 0.02*height, linewidth=1.0,head_width=0.0) #left line
                ax.arrow(4.5, current_height, 0, 0.02*height, linewidth=1.0,head_width=0.0) # right line
                ax.arrow(2.5, current_height+0.02*height, 2 ,0, linewidth=1.0,head_width=0.0) # horizontal line
                
                ax.annotate("{:.3f}".format(p).replace('0.000','<0.001'),
                            xy=(3.5,current_height+0.03*height), 
                            fontsize=10)


        plt.ylim([0,height + 0.2*height])
        plt.title(g)
        plt.savefig('./bar_plots/'+ g +'_rpkm_bar.pdf', bbox_inches='tight')
        plt.show()
        plt.close()
# Out:
# /bioinformatics/software/anaconda3/lib/python3.4/site-packages/matplotlib/__init__.py:892: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# ## Tag Scatter Plots

# %%
sns.set_style('ticks',{'axes.edgecolor': 'black',
                       'xtick.direction': 'in',
                       'ytick.direction': 'in', 
                         })

! rm ./scatter_plots/*


if not os.path.isdir('./scatter_plots'):
    os.mkdir('./scatter_plots/')
treatment_up_dict = {}
treatment_down_dict = {}
   
fdr_threshold = 0.05
fold_threshold = 2
rpkm_cutoff = 4.0
   
fdrColumns = [x for x in diffExpression_frame.columns if 'FDR' in x]


for c in fdrColumns:
        tokens = c.split()
        if 'veh' in tokens[0].lower():
            treatment1 = tokens[0]
            treatment2 = tokens[2]
        else:
            treatment1 = tokens[2]
            treatment2 = tokens[0]
        if True:
            
            fc_column = c.replace('FDR', 'logFC')

            diff_genes = diffExpression_frame[diffExpression_frame[c] < fdr_threshold]['gene'].values

            columns1 = filtered_summary_frame[filtered_summary_frame['simpleTreatment'] == treatment1]['simplifiedName']
            columns2 = filtered_summary_frame[filtered_summary_frame['simpleTreatment'] == treatment2]['simplifiedName']

            reads1 = idr_rpkm_frame.loc[:,columns1].mean(axis=1)
            reads2 = idr_rpkm_frame.loc[:,columns2].mean(axis=1)

            all_genes = idr_rpkm_frame.index.values
            read_tuple_list = tuple(zip(all_genes, reads1, reads2))
            filtered_read_tuple_list = [x for x in read_tuple_list if x[1] >= rpkm_cutoff and x[2]>= rpkm_cutoff ]
            
            filtered_genes = [x[0] for x in filtered_read_tuple_list]
            reads1 = np.array([x[1] for x in filtered_read_tuple_list])
            reads2 = np.array([x[2] for x in filtered_read_tuple_list])
            
            fold_genes = []
            for i in range(len(filtered_genes)): 
                fold = (reads1[i]+0.01)/(reads2[i]+0.01)
                if fold >=fold_threshold or fold <=1/fold_threshold:
                    fold_genes.append(filtered_genes[i])
            
#             colors = ['blue' if x in diff_genes and x in fold_genes else 'grey' if x in fold_genes else 'lightgrey' for x in idr_rpkm_frame.index.values]
#             colors = ['blue' if x in diff_genes or x in fold_genes else 'red' for x in filtered_genes]
            colors = ['blue' if x in fold_genes else 'red' for x in filtered_genes]


            # log values
            reads1 = np.log2(reads1 + 0.0000001)
            reads2 = np.log2(reads2 + 0.0000001)

            # ensure diff diff expressed genes are on top
            val_tuples = tuple(zip(reads1,reads2,colors))
            sorted_tuples = sorted(val_tuples,key=lambda x: x[2], reverse=True)
            reads1 = [x[0] for x in sorted_tuples] 
            reads2 = [x[1] for x in sorted_tuples]
            colors = [x[2] for x in sorted_tuples]
            plt.figure(figsize=(2,2))
            plt.scatter(reads1, reads2, edgecolors='none', c=colors, marker = '.', s=15)
            sns.despine()
            # fix aspect ratio
            ax = plt.gca()
            ax.set_xlim((0,12))
            ax.set_ylim((0,12))
            x0,x1 = ax.get_xlim()
            y0,y1 = ax.get_ylim()
            ax.set_aspect(abs(x1-x0)/abs(y1-y0))        
            plt.xlabel(treatment1 + ' log2 rpkm')
            plt.ylabel(treatment2 + ' log2 rpkm')
#             plt.legend(recs,classes,loc=4)
            plt.savefig('./scatter_plots/'+ treatment1 + '_' + treatment2 + '_logRPKM_scatter.png', bbox_inches='tight')
            plt.savefig('./scatter_plots/'+ treatment1 + '_' + treatment2 + '_logRPKM_scatter.pdf', bbox_inches='tight')
            plt.show()

# %% [markdown]
# ## Clustering

# %%
if not os.path.isdir('cluster_map'):
    os.mkdir('cluster_map')
treatments = sorted(list(set(filtered_summary_frame.index)))
for i in range(len(treatments) - 1):
    for j in range(i+1, len(treatments)):
        print(treatments[i], treatments[j])
        columns = list(filtered_summary_frame.loc[treatments[i],'simplifiedName']) + list(filtered_summary_frame.loc[treatments[j],'simplifiedName'])
        data = np.log2(filtered_rpkm_frame.loc[:,columns] + 1)
        data = data[data.sum(axis=1) > 0.0]
        sns.clustermap(data)
        plt.savefig('./cluster_map/' + '_'.join(treatments[i] + treatments[j]) + '_logRpkm.png')
        plt.close()

# %% [markdown]
# ## PCA Analysis

# %%
### for up-regulated genes
from matplotlib import patches as mpatches

colorDict = dict(zip(sorted(set(filtered_summary_frame['simpleTreatment'].values)), 
                 sns.color_palette("Set2") + sns.color_palette("colorblind")))

fdr_threshold = 0.05
fold_threshold = np.log2(2)
fdr_cols = [x for x in diffExpression_frame.columns if 'FDR' in x and 'vs. Vehicle' in x]
fold_cols = [x for x in diffExpression_frame.columns if 'logFC' in x and 'vs. Vehicle' in x]

down_diff_genes = diffExpression_frame[(diffExpression_frame[fdr_cols].min(axis=1) < fdr_threshold) &
                                  (diffExpression_frame[fold_cols].max(axis=1) >= fold_threshold)
                                 ]['gene'].values
down_diff_genes = [x.upper() for x in down_diff_genes]

up_diff_genes = diffExpression_frame[(diffExpression_frame[fdr_cols].min(axis=1) < fdr_threshold) &
                                  (diffExpression_frame[fold_cols].min(axis=1) <= -1*fold_threshold)
                                 ]['gene'].values
up_diff_genes = [x.upper() for x in up_diff_genes]

print('num down', len(down_diff_genes), 'num up', len(up_diff_genes))
f, axs = plt.subplots(2,1, figsize=(3,6))
plt.suptitle('PCA of Differentially Expressed Genes (2-fold)')

### down_regulated genes
features = idr_rpkm_mean_frame[idr_rpkm_mean_frame.index.isin(down_diff_genes)]
colors = [colorDict[x] for x in features.columns.values]

down_model = sklearn.decomposition.PCA(n_components=2)
reduced_features = down_model.fit_transform(features.T)
explained_variance_ratios = down_model.explained_variance_ratio_

plt.subplot(2,1,1)  
plt.scatter(reduced_features[:, 0], reduced_features[:, 1], c=colors, s=50)

plt.xlabel("1st eigenvector (" + "{:.3f}".format(explained_variance_ratios[0]) +')')
plt.xticks([])
plt.ylabel("2nd eigenvector (" + "{:.3f}".format(explained_variance_ratios[1]) +')')
plt.yticks([])
plt.title('Down-regulated Genes')

### up-regulatd genes
features = idr_rpkm_mean_frame[idr_rpkm_mean_frame.index.isin(up_diff_genes)]
colors = [colorDict[x] for x in features.columns.values]

up_model = sklearn.decomposition.PCA(n_components=2)
reduced_features = up_model.fit_transform(features.T)
explained_variance_ratios = up_model.explained_variance_ratio_

plt.subplot(2,1,2)  
plt.scatter(reduced_features[:, 0], reduced_features[:, 1], c=colors, s=50)
plt.xlabel("1st eigenvector (" + "{:.3f}".format(explained_variance_ratios[0]) +')')
plt.xticks([])
plt.ylabel("2nd eigenvector (" + "{:.3f}".format(explained_variance_ratios[1]) +')')
plt.yticks([])
plt.title('Up-regulated Genes')

# legend
classes = ['Vehicle', 'Des', 'DMHCA', 'Mepip','GW', 'T09']

classes = [x for x in classes if not '30' in x]
class_colours = [colorDict[x] for x in classes]
recs = []
for i in range(0,len(class_colours)):
    recs.append(mpatches.Rectangle((0,0),1,1,fc=class_colours[i]))
plt.legend(recs,classes,loc='right', bbox_to_anchor=(1.5, 1.0))

plt.savefig('pca_2fold.pdf',bbox_inches='tight')
plt.show()
# Out:
# num down 1191 num up 605

# %%
### for up-regulated genes
from matplotlib import patches as mpatches

colorDict = dict(zip(sorted(set(filtered_summary_frame['simpleTreatment'].values)), 
                 sns.color_palette("Set2") + sns.color_palette("colorblind")))

fdr_threshold = 0.05
fold_threshold = np.log2(1.5)
fdr_cols = [x for x in diffExpression_frame.columns if 'FDR' in x and 'vs. Vehicle' in x]
fold_cols = [x for x in diffExpression_frame.columns if 'logFC' in x and 'vs. Vehicle' in x]

down_diff_genes = diffExpression_frame[(diffExpression_frame[fdr_cols].min(axis=1) < fdr_threshold) &
                                  (diffExpression_frame[fold_cols].max(axis=1) >= fold_threshold)
                                 ]['gene'].values
down_diff_genes = [x.upper() for x in down_diff_genes]

up_diff_genes = diffExpression_frame[(diffExpression_frame[fdr_cols].min(axis=1) < fdr_threshold) &
                                  (diffExpression_frame[fold_cols].min(axis=1) <= -1*fold_threshold)
                                 ]['gene'].values
up_diff_genes = [x.upper() for x in up_diff_genes]

print('num down', len(down_diff_genes), 'num up', len(up_diff_genes))
f, axs = plt.subplots(2,1, figsize=(3,6))
plt.suptitle('PCA of Differentially Expressed Genes (1.5-fold)')

### down_regulated genes
features = idr_rpkm_mean_frame[idr_rpkm_mean_frame.index.isin(down_diff_genes)]
colors = [colorDict[x] for x in features.columns.values]

down_model = sklearn.decomposition.PCA(n_components=2)
reduced_features = down_model.fit_transform(features.T)
explained_variance_ratios = down_model.explained_variance_ratio_

plt.subplot(2,1,1)  
plt.scatter(reduced_features[:, 0], reduced_features[:, 1], c=colors, s=50)

plt.xlabel("1st eigenvector (" + "{:.3f}".format(explained_variance_ratios[0]) +')')
plt.xticks([])
plt.ylabel("2nd eigenvector (" + "{:.3f}".format(explained_variance_ratios[1]) +')')
plt.yticks([])
plt.title('Down-regulated Genes')

### up-regulatd genes
features = idr_rpkm_mean_frame[idr_rpkm_mean_frame.index.isin(up_diff_genes)]
colors = [colorDict[x] for x in features.columns.values]

up_model = sklearn.decomposition.PCA(n_components=2)
reduced_features = up_model.fit_transform(features.T)
explained_variance_ratios = up_model.explained_variance_ratio_

plt.subplot(2,1,2)  
plt.scatter(reduced_features[:, 0], reduced_features[:, 1], c=colors, s=50)
plt.xlabel("1st eigenvector (" + "{:.3f}".format(explained_variance_ratios[0]) +')')
plt.xticks([])
plt.ylabel("2nd eigenvector (" + "{:.3f}".format(explained_variance_ratios[1]) +')')
plt.yticks([])
plt.title('Up-regulated Genes')

# legend
classes = ['Vehicle', 'Des', 'DMHCA', 'Mepip','GW', 'T09']

classes = [x for x in classes if not '30' in x]
class_colours = [colorDict[x] for x in classes]
recs = []
for i in range(0,len(class_colours)):
    recs.append(mpatches.Rectangle((0,0),1,1,fc=class_colours[i]))
plt.legend(recs,classes,loc='right', bbox_to_anchor=(1.5, 1.0))

plt.savefig('pca_1.5fold.pdf',bbox_inches='tight')
plt.show()
# Out:
# num down 1267 num up 781
