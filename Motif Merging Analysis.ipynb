# %% [markdown]
# # Motif Merging Analysis

# %%
### header ###
__author__ = "Jenhan Tao"
__license__ = "BSD"
__email__ = "jenhantao@gmail.com"

### imports ###
import sys
import os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns
import pickle
import time
from collections import Counter
### notebook specific configuration ###
# %matplotlib inline
matplotlib.pylab.rcParams['savefig.dpi'] = 200
sys.setrecursionlimit(5000)
working_dir = '/gpfs/data01/glasslab/home/jtao/analysis/ap1_motif_merging/'
if not os.path.isdir(working_dir):
    os.mkdir(working_dir)
os.chdir(working_dir)
sns.set_context('notebook')
# %load_ext autoreload
# %autoreload 2

# %%
! wget http://jaspar.genereg.net/html/DOWNLOAD/JASPAR_CORE/pfm/nonredundant/pfm_vertebrates.txt

# %% [markdown]
# ### Split Jaspar motif file into individual motifs

# %%
out_dir = './jaspar_motifs/'
if not os.path.isdir(out_dir):
    os.mkdir(out_dir)
with open('./pfm_vertebrates.txt') as f:
    data = f.readlines()
counter = 0
for i in range(0,len(data),6):
    nameline = data[i][1:]
    name_tokens = nameline.strip().split()
    jaspar_id = name_tokens[0]
    name = name_tokens[1]
    
    out_file = open(out_dir + name + '.jaspar', 'w')
    for j in range(6):
        out_file.write(data[i+j])
    out_file.close()

# %% [markdown]
# ### Convert Files to TBA format

# %%
# %%bash
# if [ ! -d ./homer_motifs ];
# then
#     mkdir ./homer_motifs;
# else
#     rm ./homer_motifs/*;
# fi
#
# for i in ./jaspar_motifs/*jaspar;
#     do /gpfs/data01/glasslab/home/jtao/code/tba/jaspar2homer.py $i ${i//jaspar/homer};
# done

# %% [markdown]
# ### Clean up Motif Names

# %%
# %%bash
# for i in ./homer_motifs/*homer;
# do
#     newname=${i/(var./_var}
#     newname=${newname/)}
#     if [ ! "$i" == $newname ];
#     then
#         mv $i $newname
#     fi
# done

# %% [markdown]
# ### First Round

# %% [markdown]
# #### Score Motifs

# %%
# !python /gpfs/data01/glasslab/home/jtao/code/tba/score_motifs.py ./motif_clustering ./homer_motifs/*homer
# Out:
# Reading motif files...
# Calculating alignments between motifs and scoring motifs
# scoring against 1/519
# scoring against 2/519
# scoring against 3/519
# scoring against 4/519
# scoring against 5/519
# scoring against 6/519
# scoring against 7/519
# scoring against 8/519
# scoring against 9/519
# scoring against 10/519
# scoring against 11/519
# scoring against 12/519
# scoring against 13/519
# scoring against 14/519
# scoring against 15/519
# scoring against 16/519
# scoring against 17/519
# scoring against 18/519
# scoring against 19/519
# scoring against 20/519
# scoring against 21/519
# scoring against 22/519
# scoring against 23/519
# scoring against 24/519
# scoring against 25/519
# scoring against 26/519
# scoring against 27/519
# scoring against 28/519
# scoring against 29/519
# scoring against 30/519
# scoring against 31/519
# scoring against 32/519
# scoring against 33/519
# scoring against 34/519
# scoring against 35/519
# scoring against 36/519
# scoring against 37/519
# scoring against 38/519
# scoring against 39/519
# scoring against 40/519
# scoring against 41/519
# scoring against 42/519
# scoring against 43/519
# scoring against 44/519
# scoring against 45/519
# scoring against 46/519
# scoring against 47/519
# scoring against 48/519
# scoring against 49/519
# scoring against 50/519
# scoring against 51/519
# scoring against 52/519
# scoring against 53/519
# scoring against 54/519
# scoring against 55/519
# scoring against 56/519
# scoring against 57/519
# scoring against 58/519
# scoring against 59/519
# scoring against 60/519
# scoring against 61/519
# scoring against 62/519
# scoring against 63/519
# scoring against 64/519
# scoring against 65/519
# scoring against 66/519
# scoring against 67/519
# scoring against 408/519
# scoring against 409/519
# scoring against 410/519
# scoring against 411/519
# scoring against 412/519
# scoring against 413/519
# scoring against 414/519
# scoring against 415/519
# scoring against 416/519
# scoring against 417/519
# scoring against 418/519
# scoring against 419/519
# scoring against 420/519
# scoring against 421/519
# scoring against 422/519
# scoring against 423/519
# scoring against 424/519
# scoring against 425/519
# scoring against 426/519
# scoring against 427/519
# scoring against 428/519
# scoring against 429/519
# scoring against 430/519
# scoring against 431/519
# scoring against 432/519
# scoring against 433/519
# scoring against 434/519
# scoring against 435/519
# scoring against 436/519
# scoring against 437/519
# scoring against 438/519
# scoring against 439/519
# scoring against 440/519
# scoring against 441/519
# scoring against 442/519
# scoring against 443/519
# scoring against 444/519
# scoring against 445/519
# scoring against 446/519
# scoring against 447/519
# scoring against 448/519
# scoring against 449/519
# scoring against 450/519
# scoring against 451/519
# scoring against 452/519
# scoring against 453/519
# scoring against 454/519
# scoring against 455/519
# scoring against 456/519
# scoring against 457/519
# scoring against 458/519
# scoring against 459/519
# scoring against 460/519
# scoring against 461/519
# scoring against 462/519
# scoring against 463/519
# scoring against 464/519
# scoring against 465/519
# scoring against 466/519
# scoring against 467/519
# scoring against 468/519
# scoring against 469/519
# scoring against 470/519
# scoring against 471/519
# scoring against 472/519
# scoring against 473/519
# scoring against 474/519
# scoring against 475/519
# scoring against 476/519
# scoring against 477/519
# scoring against 478/519
# scoring against 479/519
# scoring against 480/519
# scoring against 481/519
# scoring against 482/519
# scoring against 483/519
# scoring against 484/519
# scoring against 485/519
# scoring against 486/519
# scoring against 487/519
# scoring against 488/519
# scoring against 489/519
# scoring against 490/519
# scoring against 491/519
# scoring against 492/519
# scoring against 493/519
# scoring against 494/519
# scoring against 495/519
# scoring against 496/519
# scoring against 497/519
# scoring against 498/519
# scoring against 499/519
# scoring against 500/519
# scoring against 501/519
# scoring against 502/519
# scoring against 503/519
# scoring against 504/519
# scoring against 505/519
# scoring against 506/519
# scoring against 507/519
# scoring against 508/519
# scoring against 509/519
# scoring against 510/519
# scoring against 511/519
# scoring against 512/519
# scoring against 513/519
# scoring against 514/519
# scoring against 515/519
# scoring against 516/519
# scoring against 517/519
# scoring against 518/519
# Creating visualizations...
# Serializing scores...
# correlation should be used for clustering.

# %% [markdown]
# #### Cluster Motifs

# %%
# !python /gpfs/data01/glasslab/home/jtao/code/tba/threshold_cluster_motifs.py ./motif_clustering/correlation.npz ./motif_clustering/ 0.9 ./homer_motifs/*

# %% [markdown]
# ### Second Round

# %% [markdown]
# #### Score Motifs

# %% [markdown]
# !python /gpfs/data01/glasslab/home/jtao/code/tba/score_motifs.py ./motif_clustering_round2 ./motif_clustering/clustered_motifs/*motif

# %% [markdown]
# #### Cluster Motifs

# %%
# !python /gpfs/data01/glasslab/home/jtao/code/tba/threshold_cluster_motifs.py ./motif_clustering_round2/correlation.npz ./motif_clustering_round2/ 0.9 ./motif_clustering/clustered_motifs/*motif

# %% [markdown]
# ### Convert Clustered Motifs to Fimo Format

# %%
# %%bash
# if [ ! -d ./fimo_motifs ];
# then
#     mkdir ./fimo_motifs;
# else
#     rm ./fimo_motifs/*;
# fi
#
# for i in ./motif_clustering_round2/clustered_motifs/*motif;
#     do motif_name=${i##*/};
#     /gpfs/data01/glasslab/home/jtao/code/tba/homer2fimo.py $i ./fimo_motifs/${motif_name/.motif/.fimo} ;
# done
