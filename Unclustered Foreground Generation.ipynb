# %% [markdown]
# # Unclustered Foreground Generation

# %%
### header ###
__author__ = "Jenhan Tao"
__license__ = "BSD"
__email__ = "jenhantao@gmail.com"

### imports ###
import sys
import os
import pandas as pd
import numpy as np
import matplotlib
import itertools
import scipy
import matplotlib.pyplot as plt 
import seaborn as sns
import pickle
from sklearn import preprocessing
import sklearn
from sklearn import svm, datasets
from sklearn.utils import shuffle
from sklearn.metrics import roc_curve, auc
import matplotlib_venn
from sklearn.cross_validation import train_test_split
from random import shuffle
import threading
import time
from collections import Counter
### notebook specific configuration ###
# %matplotlib inline
matplotlib.pylab.rcParams['savefig.dpi'] = 200
sys.setrecursionlimit(5000)
working_dir = '/gpfs/data01/glasslab/home/jtao/analysis/ap1_analysis_unclustered_features/'
if not os.path.isdir(working_dir):
    os.mkdir(working_dir)
os.chdir(working_dir)
sns.set_context('notebook')
# %load_ext autoreload
# %autoreload 2
# %env PATH=/gpfs/data01/glasslab/home/jtao/perl5/bin:/gpfs/data01/glasslab/home/jtao/software/anaconda3/bin:/home/jtao/software/bin:/usr/local/sbin:/usr/sbin:/usr/bin:/usr/local/bin:/usr/bin:/gpfs/data01/glasslab/home/jtao/software/homer/bin:/gpfs/data01/glasslab/home/jtao/software/weblogo:/home/jtao/code/seq_merge_pipe:/home/vlink/mouse_strains/marge/shifting:/bioinformatics/glassutils/scripts:/bioinformatics/software/meme/bin:/home/jtao/software/lsgkm/bin
# Out:
# env: PATH=/gpfs/data01/glasslab/home/jtao/perl5/bin:/gpfs/data01/glasslab/home/jtao/software/anaconda3/bin:/home/jtao/software/bin:/usr/local/sbin:/usr/sbin:/usr/bin:/usr/local/bin:/usr/bin:/gpfs/data01/glasslab/home/jtao/software/homer/bin:/gpfs/data01/glasslab/home/jtao/software/weblogo:/home/jtao/code/seq_merge_pipe:/home/vlink/mouse_strains/marge/shifting:/bioinformatics/glassutils/scripts:/bioinformatics/software/meme/bin:/home/jtao/software/lsgkm/bin

# %% [markdown]
# ## copy motif files

# %%
# %%bash
# if [ ! -d ./fimo_motifs ]; then mkdir ./fimo_motifs; else rm ./fimo_motifs/*; fi
# for f in /gpfs/data01/glasslab/home/jtao/analysis/ap1_motif_merging/homer_motifs/*;
# do motif=${f##*/};
# motif=${motif%.homer}
# /gpfs/data01/glasslab/home/jtao/code/tba/homer2fimo.py $f ./fimo_motifs/${motif}.fimo
# done

# %%
# %%bash
# cp /gpfs/data01/glasslab/home/jtao/analysis/ap1_analysis_features/summary_frame.tsv ./
# cp /gpfs/data01/glasslab/home/jtao/analysis/ap1_analysis_background_features/background_group_summary.tsv ./
# Out:
# cp: cannot stat ‘/gpfs/data01/glasslab/home/jtao/analysis/ap1_analysis_features/summary_frame.tsv’: No such file or directory

# %%
# read in peak data data
summary_frame = pd.read_csv('./group_summary.tsv' , sep='\t')
summary_frame = summary_frame.fillna('0')
for col in summary_frame.columns[5:]:
    floatValues = []
    for val in summary_frame[col].values.astype(str):
        if ',' in val:
            maxVal = np.mean([float(x) for x in val.split(',')])
            floatValues.append(maxVal)
        else:
            floatValues.append(float(val))
    summary_frame[col] = floatValues
summary_frame.index = summary_frame['ID'].values

# remove peaks in unknown/random chromosomes
summary_frame = summary_frame[~summary_frame['chr'].str.contains('random')]
summary_frame = summary_frame[~summary_frame['chr'].str.contains('Un')]
# Out:
# /gpfs/data01/glasslab/home/jtao/software/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (5,7,8,9,11,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# read in peak data data
summary_background_frame = pd.read_csv('./background_group_summary.tsv' , sep='\t')
summary_background_frame = summary_background_frame.fillna('0')
for col in summary_background_frame.columns[5:]:
    floatValues = []
    for val in summary_background_frame[col].values.astype(str):
        if ',' in val:
            maxVal = np.mean([float(x) for x in val.split(',')])
            floatValues.append(maxVal)
        else:
            floatValues.append(float(val))
    summary_background_frame[col] = floatValues
summary_background_frame.index = summary_background_frame['ID'].values
# Out:
# /gpfs/data01/glasslab/home/jtao/software/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (5,6,7,8,9,10,11,13,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Retrieve Sequences Under Peaks

# %%
# %%bash
# if [ ! -d ./peak_sequences ] ;
#     then mkdir ./peak_sequences
# else
#     rm ./peak_sequences/*
# fi

# %%
# %%bash
# cp /gpfs/data01/glasslab/home/jtao/analysis/ap1_analysis_features/peak_sequences/C57BL6J.fa ./peak_sequences/
# cp /gpfs/data01/glasslab/home/jtao/analysis/ap1_analysis_background_features/peak_sequences/C57BL6J.fa ./peak_sequences/C57BL6J-background.fa

# %% [markdown]
# ### create a script to scan for motifs using FIMO

# %%
# create a script to scan for motifs using FIMO
! if [ ! -d /home/jtao/analysis/cobinding_motif_analysis/fimo_results/ ]; then mkdir /home/jtao/analysis/cobinding_motif_analysis/fimo_results/; fi
! rm -rf fimo_out/*
! rm -rf fimo_result/*


pthresh = 0.01
motif_dir = './fimo_motifs/'

fimo_results_dir = './fimo_results'

for fastaFile in os.listdir('./peak_sequences/'):
    if not 'marge' in fastaFile:
        print(fastaFile)
        strain = fastaFile.split('.')[0]
        count = 0
        scriptFile = open('scanMotifs_'+ strain +'.sh','w')
        for m in sorted(os.listdir(motif_dir)):
            if '.fimo' in m:
                fimo_out_dir = './fimo_out/' + strain + '_' +m.replace('.fimo','')
                outPath = fimo_results_dir + '/' +strain + '_' + m.replace('.fimo','') +'.txt'
                scriptFile.write(
        #             '(sleep ' + str(15 * count) + 
                    '(sleep ' + str(0 * count) + 
                    's; fimo --text --max-stored-scores 2000000 --output-pthresh ' + 
                    str(pthresh) +' --oc ' + fimo_out_dir + ' ' +
                    motif_dir + '/' + m + ' ./peak_sequences/' + fastaFile +
                    '> ' + outPath + ' ) & \n')
                count+=1
        scriptFile.close()
# Out:
# C57BL6J.fa
# C57BL6J-background.fa

# %%
# %%bash
# if [ ! -d ./fimo_results ]; then mkdir ./fimo_results; else rm -rf ./fimo_results/*; fi
# chmod a+x ./scanMotifs*
# ./scanMotifs_C57BL6J.sh
# ./scanMotifs_C57BL6J-background.sh
# Out:
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +ARNT::HIF1A of width 8.
# Using motif -ARNT::HIF1A of width 8.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +ALX3 of width 10.
# Using motif -ALX3 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +ATF4 of width 13.
# Using motif -ATF4 of width 13.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Ar of width 17.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Using motif -Ar of width 17.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +ATF7 of width 14.
# Read 1 motifs.
# Using motif +Ahr::Arnt of width 6.
# Using motif -Ahr::Arnt of width 6.
# Using motif -ATF7 of width 14.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Alx4 of width 17.
# Warning: text mode turns off computation of q-values
# Using motif -Alx4 of width 17.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Alx1 of width 17.
# Using motif -Alx1 of width 17.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Arid3b of width 11.
# Warning: text mode turns off computation of q-values
# Using motif -Arid3b of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +Arid3a of width 6.
# Using motif -Arid3a of width 6.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +NFYA of width 18.
# Using motif -NFYA of width 18.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Arid5a of width 14.
# Using motif -Arid5a of width 14.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Using motif +Arntl of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif -Arntl of width 10.
# Using motif +Arnt of width 6.
# Using motif -Arnt of width 6.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Arx of width 17.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -Arx of width 17.
# Read 1 motifs.
# Using motif +Atf3 of width 8.
# Using motif -Atf3 of width 8.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Atf1 of width 8.
# Using motif -Atf1 of width 8.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Ascl2 of width 10.
# Using motif -Ascl2 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +NR2F1 of width 13.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Atoh1 of width 10.
# Using motif -NR2F1 of width 13.
# Using motif -Atoh1 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +BARHL2 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -BARHL2 of width 10.
# Read 1 motifs.
# Using motif +BATF::JUN of width 11.
# Using motif -BATF::JUN of width 11.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Nkx3-1 of width 9.
# Using motif -Nkx3-1 of width 9.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Nkx2-5(var.2) of width 11.
# Using motif -Nkx2-5(var.2) of width 11.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using motif +Nr2e1 of width 9.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -Nr2e1 of width 9.
# Read 1 motifs.
# Using motif +Nr5a2 of width 15.
# Using motif -Nr5a2 of width 15.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Nr2f6(var.2) of width 15.
# Using motif -Nr2f6(var.2) of width 15.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +BARX1 of width 8.
# Warning: text mode turns off computation of q-values
# Using motif -BARX1 of width 8.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +BATF3 of width 14.
# Using motif -BATF3 of width 14.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Read 1 motifs.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +BHLHE23 of width 12.
# Read 1 motifs.
# Using motif +BCL6B of width 17.
# Read 1 motifs.
# Using motif -BHLHE23 of width 12.
# Using motif +BHLHE22 of width 10.
# Using motif -BHLHE22 of width 10.
# Using motif -BCL6B of width 17.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Using motif +BHLHE41 of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif -BHLHE41 of width 10.
# Read 1 motifs.
# Using motif +BSX of width 8.
# Using motif +BHLHE40 of width 10.
# Using motif -BSX of width 8.
# Using motif -BHLHE40 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +PBX1 of width 12.
# Read 1 motifs.
# Using motif +Bach1::Mafk of width 15.
# Using motif -PBX1 of width 12.
# Using motif -Bach1::Mafk of width 15.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Barhl1 of width 10.
# Using motif -Barhl1 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +CDX1 of width 9.
# Using motif -CDX1 of width 9.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Bcl6 of width 14.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -Bcl6 of width 14.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +PAX1 of width 17.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Bhlha15 of width 8.
# Using motif -Bhlha15 of width 8.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -PAX1 of width 17.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Using motif +CDX2 of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif -CDX2 of width 11.
# Using motif +CEBPB of width 10.
# Using motif -CEBPB of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Warning: text mode turns off computation of q-values
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +CEBPE of width 10.
# Read 1 motifs.
# Using motif +CEBPD of width 10.
# Using motif -CEBPE of width 10.
# Using motif -CEBPD of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +RUNX2 of width 9.
# Using motif -RUNX2 of width 9.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +CEBPA of width 11.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -CEBPA of width 11.
# Read 1 motifs.
# Using motif +Stat4 of width 14.
# Using motif -Stat4 of width 14.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +CENPB of width 15.
# Using motif -CENPB of width 15.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +CEBPG of width 10.
# Read 1 motifs.
# Read 1 motifs.
# Using motif +CLOCK of width 10.
# Using motif +TEF of width 12.
# Warning: text mode turns off computation of q-values
# Using motif -CEBPG of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -CLOCK of width 10.
# Using motif -TEF of width 12.
# Read 1 motifs.
# Using motif +CREB3 of width 14.
# Using motif -CREB3 of width 14.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +CTCF of width 19.
# Using motif -CTCF of width 19.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +Sox3 of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -Sox3 of width 10.
# Read 1 motifs.
# Read 1 motifs.
# Using motif +CREB3L1 of width 14.
# Using motif +CREB1 of width 8.
# Using motif -CREB1 of width 8.
# Using motif -CREB3L1 of width 14.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +TFEB of width 10.
# Using motif -TFEB of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +TCF7L2 of width 14.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -TCF7L2 of width 14.
# Read 1 motifs.
# Using motif +TCF4 of width 10.
# Using motif -TCF4 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +TBX1 of width 8.
# Using motif -TBX1 of width 8.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +TBX5 of width 8.
# Using motif -TBX5 of width 8.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +CUX1 of width 10.
# Using motif -CUX1 of width 10.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Read 1 motifs.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Warning: text mode turns off computation of q-values
# Using background frequencies from NR sequence database.
# Using motif +SPDEF of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Using motif -SPDEF of width 11.
# Using motif +Crem of width 10.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +DBP of width 12.
# Using motif +Creb5 of width 12.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using motif -Crem of width 10.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using motif -DBP of width 12.
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Using motif +Creb3l2 of width 9.
# Using motif -Creb5 of width 12.
# Warning: text mode turns off computation of q-values
# Using motif +DUX4 of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif -DUX4 of width 11.
# Read 1 motifs.
# Using motif +DMRT3 of width 11.
# Using motif +Crx of width 11.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Using motif -DMRT3 of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Warning: text mode turns off computation of q-values
# Using background frequencies from NR sequence database.
# Using motif -Crx of width 11.
# Using motif -Creb3l2 of width 9.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Read 1 motifs.
# Using motif +Dlx2 of width 8.
# Using motif +Ddit3::Cebpa of width 12.
# Using motif +DLX6 of width 8.
# Read 1 motifs.
# Using motif -Dlx2 of width 8.
# Using motif +DUXA of width 13.
# Using motif -DLX6 of width 8.
# Using motif -Ddit3::Cebpa of width 12.
# Using motif -DUXA of width 13.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Using motif +Rarg of width 16.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +Dlx1 of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -Dlx1 of width 10.
# Warning: text mode turns off computation of q-values
# Using motif -Rarg of width 16.
# Read 1 motifs.
# Using motif +Dlx4 of width 8.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -Dlx4 of width 8.
# Read 1 motifs.
# Using motif +Dlx3 of width 8.
# Using motif -Dlx3 of width 8.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +E2F1 of width 12.
# Using motif -E2F1 of width 12.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +CUX2 of width 10.
# Using motif -CUX2 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +Dmbx1 of width 17.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Dux of width 8.
# Read 1 motifs.
# Using motif -Dmbx1 of width 17.
# Using motif -Dux of width 8.
# Using motif +E2F3 of width 18.
# Using motif -E2F3 of width 18.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Using motif +TFEC of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Read 1 motifs.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using motif -TFEC of width 10.
# Using background frequencies from NR sequence database.
# Using motif +E2F6 of width 11.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using motif +E2F2 of width 16.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -E2F6 of width 11.
# Read 1 motifs.
# Using motif +E2F4 of width 11.
# Using motif -E2F4 of width 11.
# Using motif -E2F2 of width 16.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +E2F7 of width 14.
# Using motif -E2F7 of width 14.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +TFAP2A(var.2) of width 12.
# Using motif -TFAP2A(var.2) of width 12.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +EBF1 of width 14.
# Read 1 motifs.
# Using motif +E2F8 of width 12.
# Using motif -E2F8 of width 12.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -EBF1 of width 14.
# Read 1 motifs.
# Using motif +Stat5a::Stat5b of width 11.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Using motif -Stat5a::Stat5b of width 11.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +EGR2 of width 11.
# Read 1 motifs.
# Using motif +EGR1 of width 14.
# Using motif -EGR2 of width 11.
# Using motif -EGR1 of width 14.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +EGR3 of width 15.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -EGR3 of width 15.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +EGR4 of width 16.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +ELF1 of width 12.
# Using motif -EGR4 of width 16.
# Using motif -ELF1 of width 12.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +EHF of width 12.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -EHF of width 12.
# Read 1 motifs.
# Using motif +ELF3 of width 13.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -ELF3 of width 13.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Using motif +ELF4 of width 12.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif -ELF4 of width 12.
# Using motif +ELK1 of width 10.
# Using motif -ELK1 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +ELF5 of width 11.
# Using motif -ELF5 of width 11.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +ELK3 of width 10.
# Warning: text mode turns off computation of q-values
# Using motif -ELK3 of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +ELK4 of width 11.
# Using motif -ELK4 of width 11.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +EMX2 of width 10.
# Using motif -EMX2 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +EMX1 of width 10.
# Warning: text mode turns off computation of q-values
# Using motif -EMX1 of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +EN1 of width 8.
# Warning: text mode turns off computation of q-values
# Using motif -EN1 of width 8.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +EN2 of width 10.
# Using motif -EN2 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Using motif +ERF of width 10.
# Using motif +EOMES of width 13.
# Using motif -ERF of width 10.
# Using motif -EOMES of width 13.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +ERG of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -ERG of width 10.
# Read 1 motifs.
# Using motif +ESR1 of width 17.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +ESR2 of width 15.
# Using motif -ESR1 of width 17.
# Using motif -ESR2 of width 15.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using background frequencies from NR sequence database.
# Using motif +ESX1 of width 10.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif -ESX1 of width 10.
# Using motif +ETS1 of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Using motif -ETS1 of width 10.
# Using motif +ETV2 of width 11.
# Using motif +ESRRB of width 11.
# Using motif -ETV2 of width 11.
# Using motif -ESRRB of width 11.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Read 1 motifs.
# Using motif +ETV3 of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using motif +ETV1 of width 10.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif -ETV1 of width 10.
# Using motif -ETV3 of width 10.
# Using motif +ETV4 of width 10.
# Using motif -ETV4 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Warning: text mode turns off computation of q-values
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Read 1 motifs.
# Using background frequencies from NR sequence database.
# Using motif +ETV6 of width 10.
# Read 1 motifs.
# Using motif +EVX1 of width 10.
# Using motif -ETV6 of width 10.
# Using motif -EVX1 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +EVX2 of width 10.
# Using motif -EVX2 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using motif +FEV of width 10.
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif -FEV of width 10.
# Using motif +FIGLA of width 10.
# Using motif -FIGLA of width 10.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Esrrg of width 10.
# Read 1 motifs.
# Using motif +FLI1 of width 10.
# Using motif -Esrrg of width 10.
# Using motif -FLI1 of width 10.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using background frequencies from NR sequence database.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Using motif +ETV5 of width 10.
# Using motif +FOS of width 11.
# Using motif -ETV5 of width 10.
# Warning: text mode turns off computation of q-values
# Using motif -FOS of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +FOS::JUN of width 7.
# Using motif -FOS::JUN of width 7.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +FOSL1 of width 11.
# Using motif -FOSL1 of width 11.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +FOSL2 of width 11.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using background frequencies from NR sequence database.
# Using motif -FOSL2 of width 11.
# Read 1 motifs.
# Read 1 motifs.
# Using motif +Esrra of width 11.
# Using motif +FOXA1 of width 15.
# Warning: text mode turns off computation of q-values
# Using motif -Esrra of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -FOXA1 of width 15.
# Read 1 motifs.
# Using motif +FOXB1 of width 11.
# Using motif -FOXB1 of width 11.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +EWSR1-FLI1 of width 18.
# Using motif -EWSR1-FLI1 of width 18.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +FOXC1 of width 11.
# Using motif -FOXC1 of width 11.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +FOXC2 of width 12.
# Using motif -FOXC2 of width 12.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +FOXD2 of width 7.
# Using motif -FOXD2 of width 7.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +FOXG1 of width 8.
# Read 1 motifs.
# Using motif +FOXF2 of width 14.
# Using motif -FOXG1 of width 8.
# Using motif -FOXF2 of width 14.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +FOXH1 of width 11.
# Warning: text mode turns off computation of q-values
# Using motif -FOXH1 of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +FOXL1 of width 7.
# Using motif -FOXL1 of width 7.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +FOXI1 of width 7.
# Using motif -FOXI1 of width 7.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +FOXO6 of width 7.
# Using motif -FOXO6 of width 7.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +FOXO3 of width 8.
# Using motif -FOXO3 of width 8.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +FOXO4 of width 7.
# Using motif -FOXO4 of width 7.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +FOXD1 of width 8.
# Using motif -FOXD1 of width 8.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +FOXP1 of width 15.
# Read 1 motifs.
# Using motif +FOXP2 of width 11.
# Using motif -FOXP2 of width 11.
# Using motif -FOXP1 of width 15.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +FOXP3 of width 7.
# Using motif -FOXP3 of width 7.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Foxa2 of width 12.
# Using motif -Foxa2 of width 12.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Foxj2 of width 8.
# Using motif -Foxj2 of width 8.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Foxd3 of width 12.
# Using motif -Foxd3 of width 12.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Foxj3 of width 17.
# Using motif -Foxj3 of width 17.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Using motif +Foxq1 of width 11.
# Using motif +Foxk1 of width 17.
# Using motif -Foxq1 of width 11.
# Using motif -Foxk1 of width 17.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +Foxo1 of width 11.
# Read 1 motifs.
# Using motif -Foxo1 of width 11.
# Using motif +GATA1::TAL1 of width 18.
# Using motif -GATA1::TAL1 of width 18.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Using motif +GATA3 of width 8.
# Using motif +GATA5 of width 8.
# Using motif -GATA3 of width 8.
# Using motif -GATA5 of width 8.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Using motif +GBX1 of width 10.
# Using motif +GATA2 of width 14.
# Using motif -GBX1 of width 10.
# Using motif -GATA2 of width 14.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Using motif +GCM1 of width 11.
# Warning: text mode turns off computation of q-values
# Using motif +GLI2 of width 12.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -GCM1 of width 11.
# Using motif -GLI2 of width 12.
# Read 1 motifs.
# Using motif +GLIS1 of width 16.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Using motif -GLIS1 of width 16.
# Using motif +GLIS3 of width 14.
# Using motif +GCM2 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -GCM2 of width 10.
# Warning: text mode turns off computation of q-values
# Using motif -GLIS3 of width 14.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# ...
# Read 1 motifs.
# Read 1 motifs.
# Using motif +TFAP2A(var.3) of width 13.
# Using motif +TBX1 of width 8.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -TBX1 of width 8.
# Using motif -TFAP2A(var.3) of width 13.
# Read 1 motifs.
# Using motif +Tcf12 of width 11.
# Using motif -Tcf12 of width 11.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +THAP1 of width 9.
# Using motif -THAP1 of width 9.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +TFEC of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -TFEC of width 10.
# Read 1 motifs.
# Using motif +STAT1::STAT2 of width 15.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Using motif -STAT1::STAT2 of width 15.
# Using motif +XBP1 of width 14.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Twist2 of width 10.
# Using motif -XBP1 of width 14.
# Using motif -Twist2 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +TFAP2B(var.3) of width 13.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -TFAP2B(var.3) of width 13.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +TFAP2C(var.2) of width 11.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -TFAP2C(var.2) of width 11.
# Read 1 motifs.
# Using motif +Vdr of width 16.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Using motif +TP73 of width 18.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using background frequencies from NR sequence database.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Using motif +TFAP2A(var.2) of width 12.
# Using motif +TEAD1 of width 10.
# Using motif -Vdr of width 16.
# Using motif -TP73 of width 18.
# Using motif -TEAD1 of width 10.
# Using motif -TFAP2A(var.2) of width 12.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +TCF4 of width 10.
# Using motif -TCF4 of width 10.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using motif +Tcf7 of width 12.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +TFEB of width 10.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +ZBTB7B of width 12.
# Using motif -Tcf7 of width 12.
# Using motif -TFEB of width 10.
# Read 1 motifs.
# Using motif +ZBTB7C of width 12.
# Using motif -ZBTB7B of width 12.
# Using motif -ZBTB7C of width 12.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +ZEB1 of width 9.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Using motif -ZEB1 of width 9.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +TFAP2C(var.3) of width 13.
# Using motif +VENTX of width 9.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using motif +TEF of width 12.
# Using background frequencies from NR sequence database.
# Using motif -VENTX of width 9.
# Read 1 motifs.
# Using motif -TFAP2C(var.3) of width 13.
# Using motif +TFCP2 of width 10.
# Using motif -TEF of width 12.
# Using motif -TFCP2 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +TP63 of width 18.
# Using motif -TP63 of width 18.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Read 1 motifs.
# Using background frequencies from NR sequence database.
# Using motif +VSX2 of width 8.
# Using motif +YY2 of width 11.
# Read 1 motifs.
# Using motif -VSX2 of width 8.
# Using motif +TCF3 of width 10.
# Using motif -YY2 of width 11.
# Using motif -TCF3 of width 10.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Using motif +USF2 of width 11.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Read 1 motifs.
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Using motif +ZBTB18 of width 13.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Read 1 motifs.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -USF2 of width 11.
# Using motif +ZIC3 of width 15.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Using motif +VAX1 of width 8.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -ZBTB18 of width 13.
# Using motif -VAX1 of width 8.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Using motif -ZIC3 of width 15.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +VAX2 of width 8.
# Read 1 motifs.
# Using motif -VAX2 of width 8.
# Using motif +TFAP4 of width 10.
# Using motif -TFAP4 of width 10.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Read 1 motifs.
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using motif +TP53 of width 18.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Warning: text mode turns off computation of q-values
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +ZNF410 of width 17.
# Using motif +TFAP2B(var.2) of width 11.
# Read 1 motifs.
# Using motif -TFAP2B(var.2) of width 11.
# Using motif -TP53 of width 18.
# Using motif +TGIF1 of width 12.
# Warning: text mode turns off computation of q-values
# Using motif -ZNF410 of width 17.
# Warning: text mode turns off computation of q-values
# Using motif -TGIF1 of width 12.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using background frequencies from NR sequence database.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Warning: text mode turns off computation of q-values
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Read 1 motifs.
# Using motif +ZIC1 of width 14.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +ZBTB7A of width 12.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Warning: text mode turns off computation of q-values
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -ZIC1 of width 14.
# Using motif -ZBTB7A of width 12.
# Read 1 motifs.
# Using motif +ZBED1 of width 13.
# Read 1 motifs.
# Using motif +ZIC4 of width 15.
# Warning: text mode turns off computation of q-values
# Using motif -ZBED1 of width 13.
# Using motif -ZIC4 of width 15.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +ZBTB33 of width 15.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +ZNF143 of width 16.
# Read 1 motifs.
# Using motif -ZBTB33 of width 15.
# Using motif +USF1 of width 11.
# Warning: text mode turns off computation of q-values
# Using motif -USF1 of width 11.
# Using motif -ZNF143 of width 16.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Using motif +ZNF740 of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -ZNF740 of width 10.
# Read 1 motifs.
# Using motif +TFE3 of width 10.
# Warning: text mode turns off computation of q-values
# Using motif -TFE3 of width 10.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +Zfx of width 14.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using motif +Tcfl5 of width 10.
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -Zfx of width 14.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Using motif -Tcfl5 of width 10.
# Using motif +Znf423 of width 15.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Warning: text mode turns off computation of q-values
# Using motif +YY1 of width 12.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif -Znf423 of width 15.
# Read 1 motifs.
# Using motif +ZNF354C of width 6.
# Using motif -YY1 of width 12.
# Using motif -ZNF354C of width 6.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +VSX1 of width 8.
# Using motif -VSX1 of width 8.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +UNCX of width 8.
# Warning: text mode turns off computation of q-values
# Using motif -UNCX of width 8.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Read 1 motifs.
# Using motif +Tcf21 of width 14.
# Using motif -Tcf21 of width 14.
# Using motif +TGIF2 of width 12.
# Using motif -TGIF2 of width 12.
# Warning: text mode turns off computation of q-values
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Warning: text mode turns off computation of q-values
# Read 1 motifs.
# Reading txt file vmajor: 4, vminor: 4, vbug: 0
# Using nucleotide alphabet (ACGTURYKMSWBDHVN).
# Using background frequencies from NR sequence database.
# Using motif +ZNF263 of width 21.
# Read 1 motifs.
# Using motif +mix-a of width 11.
# Using motif -mix-a of width 11.
# Using motif -ZNF263 of width 21.

# %% [markdown]
# ## Read in Motif Scores

# %%
def read_fimo_file(thread_lock, motif_results_path, 
                   all_peak_ids,
                   motif_score_dict,
                   motif_sequence_dict,
                   motif_strand_dict,
                   motif_start_dict,
                   motif_end_dict,
                   motif_count_dict,
                  ):
    
    # read in fimo result as data frame
    fimo_result_frame=pd.read_csv(motif_results_path, 
                                  skiprows=1,
                                  names=['motif_name', 
                                         'peak_id', 
                                         'start', 
                                         'stop', 
                                         'strand', 
                                         'score', 
                                         'pvalue', 
                                         'sequence'],
                                  sep='\t')
    motif_name = fimo_result_frame['motif_name'].values[0]
    print('reading', motif_name)
    
    id_values_dict = {} # {PeakID:(motifScore, motifSequence, motifStrand, motifStart, motifEnd)}
    # drop all motif instances that has less than the maximum score
    sorted_fimo_result_frame = fimo_result_frame.sort_values(by='score', ascending=False)
    top_fimo_result_frame = sorted_fimo_result_frame.drop_duplicates(subset='peak_id')
    
    # convert data frame to a dictionary 
    unique_peak_ids = top_fimo_result_frame['peak_id'].values
    scores = top_fimo_result_frame['score'].values
    strands = top_fimo_result_frame['strand'].values
    sequences = top_fimo_result_frame['sequence'].values
    starts = top_fimo_result_frame['start'].values
    ends = top_fimo_result_frame['stop'].values
    
    for i in range(len(unique_peak_ids)):
        currentPeakID = unique_peak_ids[i]
        currentScore = float(scores[i])
        currentSequence = sequences[i]
        currentStrand = strands[i]
        currentStart = int(starts[i])
        currentEnd = int(ends[i])
        # bundle values
        
        if currentScore < 0.0:
            currentScore = 0.0
        
        newValues = (currentScore, 
                     currentSequence, 
                     currentStrand, 
                     currentStart, 
                     currentEnd, 
                     )
        id_values_dict[currentPeakID] = newValues
    
    # sort values according to all peak IDs
    sorted_values = [id_values_dict[x] if x in id_values_dict else (0,'','?',-1,-1) for x in  all_peak_ids]
    sorted_scores = [x[0] for x in sorted_values]
    sorted_sequences = [x[1] for x in sorted_values]
    sorted_strands = [x[2] for x in sorted_values]
    sorted_starts = [x[3] for x in sorted_values]
    sorted_ends = [x[4] for x in sorted_values]
    
    # count the number of motif instances
    peak_ids = fimo_result_frame['peak_id'].values
    id_count_dict = Counter(peak_ids)
    
    sorted_counts = [id_count_dict[x] if x in id_count_dict else 0 for x in all_peak_ids]
    del fimo_result_frame # release result frame from memory hopefully
    while thread_lock.locked_lock():
        pass
    thread_lock.acquire()
        
    motif_score_dict[motif_name] = sorted_scores
    motif_sequence_dict[motif_name] = sorted_sequences
    motif_strand_dict[motif_name] = sorted_strands
    motif_start_dict[motif_name] = sorted_starts
    motif_end_dict[motif_name] = sorted_ends
    motif_count_dict[motif_name] = sorted_counts
    # release lock
    print('finished reading', motif_name )
    if thread_lock.locked_lock():
        thread_lock.release()
    
    return None

# %%
start = time.time()
fimo_result_path = './fimo_results/'
for fastaFile in os.listdir('./peak_sequences/'):
    if not 'marge' in fastaFile:
        print('*****',fastaFile,'*****')
        strain = fastaFile.split('.')[0]
        motif_score_dict = {}
        motif_sequence_dict ={}
        motif_strand_dict = {}
        motif_start_dict = {}
        motif_end_dict = {}
        motif_count_dict = {}
        thread_list = []
        
        for current_thread in thread_list:
            current_thread.join()
        if 'background' in fastaFile:
            current_summary_frame = summary_background_frame
        else:
            current_summary_frame = summary_frame
        all_peak_ids = current_summary_frame.index.values
        lock = threading.Lock()
        for m in sorted(os.listdir('./fimo_results')):
            if (strain + '_') in m:
                try:
                    print(m)
                    current_thread = threading.Thread(target = read_fimo_file,
                                     args =(lock,
                                            fimo_result_path + '/' + m, 
                                            all_peak_ids,
                                            motif_score_dict,
                                            motif_sequence_dict,
                                            motif_strand_dict,
                                            motif_start_dict,
                                            motif_end_dict,
                                            motif_count_dict,
                                            ))
                    thread_list.append(current_thread)
                    current_thread.start()
                finally:
                    if lock.locked_lock():
                        lock.release()

        # convert dictionaries to data frames
        motif_score_frame = pd.DataFrame(motif_score_dict , index = current_summary_frame['ID'].values)
        motif_sequence_frame = pd.DataFrame(motif_sequence_dict , index = current_summary_frame['ID'].values)
        motif_strand_frame = pd.DataFrame(motif_strand_dict , index = current_summary_frame['ID'].values)
        motif_start_frame = pd.DataFrame(motif_start_dict , index = current_summary_frame['ID'].values)
        motif_end_frame = pd.DataFrame(motif_end_dict , index = current_summary_frame['ID'].values)
        motif_count_frame = pd.DataFrame(motif_count_dict , index = current_summary_frame['ID'].values)

        for frame in [motif_score_frame, 
                      motif_sequence_frame, 
                      motif_strand_frame, 
                      motif_start_frame, 
                      motif_end_frame, 
                      motif_count_frame]:
            motif_cols = frame.columns.values
            frame['ID'] = current_summary_frame['ID'].values
            frame['Factors'] = current_summary_frame['Factors'].values
            frame['chr'] = current_summary_frame['chr'].values

        motif_score_frame.to_pickle('motif_score_unclustered_frame_'+  strain + '.pickle')

        motif_sequence_frame.to_pickle('motif_sequence_unclustered_frame_'+  strain + '.pickle')

        motif_strand_frame.to_pickle('motif_strand_unclustered_frame_'+  strain + '.pickle')

        motif_start_frame.to_pickle('motif_start_unclustered_frame_'+  strain + '.pickle')

        motif_end_frame.to_pickle('motif_end_unclustered_frame_'+  strain + '.pickle')

        motif_count_frame.to_pickle('motif_count_unclustered_frame_'+  strain + '.pickle')
        
end = time.time()
print('total time', end - start)
# Out:
# ***** C57BL6J-background.fa *****
# C57BL6J-background_ALX3.txt
# C57BL6J-background_ARNT::HIF1A.txt
# C57BL6J-background_ATF4.txt
# C57BL6J-background_ATF7.txt
# C57BL6J-background_Ahr::Arnt.txt
# C57BL6J-background_Alx1.txt
# C57BL6J-background_Alx4.txt
# C57BL6J-background_Ar.txt
# C57BL6J-background_Arid3a.txt
# C57BL6J-background_Arid3b.txt
# C57BL6J-background_Arid5a.txt
# C57BL6J-background_Arnt.txt
# C57BL6J-background_Arntl.txt
# C57BL6J-background_Arx.txt
# C57BL6J-background_Ascl2.txt
# C57BL6J-background_Atf1.txt
# C57BL6J-background_Atf3.txt
# C57BL6J-background_Atoh1.txt
# C57BL6J-background_BARHL2.txt
# C57BL6J-background_BARX1.txt
# C57BL6J-background_BATF3.txt
# C57BL6J-background_BATF::JUN.txt
# C57BL6J-background_BCL6B.txt
# C57BL6J-background_BHLHE22.txt
# C57BL6J-background_BHLHE23.txt
# C57BL6J-background_BHLHE40.txt
# C57BL6J-background_BHLHE41.txt
# C57BL6J-background_BSX.txt
# C57BL6J-background_Bach1::Mafk.txt
# C57BL6J-background_Barhl1.txt
# C57BL6J-background_Bcl6.txt
# C57BL6J-background_Bhlha15.txt
# C57BL6J-background_CDX1.txt
# C57BL6J-background_CDX2.txt
# C57BL6J-background_CEBPA.txt
# C57BL6J-background_CEBPB.txt
# C57BL6J-background_CEBPD.txt
# C57BL6J-background_CEBPE.txt
# C57BL6J-background_CEBPG.txt
# C57BL6J-background_CENPB.txt
# C57BL6J-background_CLOCK.txt
# C57BL6J-background_CREB1.txt
# C57BL6J-background_CREB3.txt
# C57BL6J-background_CREB3L1.txt
# C57BL6J-background_CTCF.txt
# C57BL6J-background_CUX1.txt
# C57BL6J-background_CUX2.txt
# C57BL6J-background_Creb3l2.txt
# C57BL6J-background_Creb5.txt
# C57BL6J-background_Crem.txt
# C57BL6J-background_Crx.txt
# C57BL6J-background_DBP.txt
# C57BL6J-background_DLX6.txt
# C57BL6J-background_DMRT3.txt
# C57BL6J-background_DUX4.txt
# C57BL6J-background_DUXA.txt
# C57BL6J-background_Ddit3::Cebpa.txt
# C57BL6J-background_Dlx1.txt
# C57BL6J-background_Dlx2.txt
# C57BL6J-background_Dlx3.txt
# C57BL6J-background_Dlx4.txt
# C57BL6J-background_Dmbx1.txt
# C57BL6J-background_Dux.txt
# C57BL6J-background_E2F1.txt
# C57BL6J-background_E2F2.txt
# C57BL6J-background_E2F3.txt
# C57BL6J-background_E2F4.txt
# C57BL6J-background_E2F6.txt
# C57BL6J-background_E2F7.txt
# C57BL6J-background_E2F8.txt
# C57BL6J-background_EBF1.txt
# C57BL6J-background_EGR1.txt
# C57BL6J-background_EGR2.txt
# C57BL6J-background_EGR3.txt
# C57BL6J-background_EGR4.txt
# C57BL6J-background_EHF.txt
# C57BL6J-background_ELF1.txt
# C57BL6J-background_ELF3.txt
# C57BL6J-background_ELF4.txt
# C57BL6J-background_ELF5.txt
# C57BL6J-background_ELK1.txt
# C57BL6J-background_ELK3.txt
# C57BL6J-background_ELK4.txt
# C57BL6J-background_EMX1.txt
# C57BL6J-background_EMX2.txt
# C57BL6J-background_EN1.txt
# C57BL6J-background_EN2.txt
# C57BL6J-background_EOMES.txt
# C57BL6J-background_ERF.txt
# C57BL6J-background_ERG.txt
# C57BL6J-background_ESR1.txt
# C57BL6J-background_ESR2.txt
# C57BL6J-background_ESRRB.txt
# C57BL6J-background_ESX1.txt
# C57BL6J-background_ETS1.txt
# C57BL6J-background_ETV1.txt
# C57BL6J-background_ETV2.txt
# C57BL6J-background_ETV3.txt
# C57BL6J-background_ETV4.txt
# C57BL6J-background_ETV5.txt
# C57BL6J-background_ETV6.txt
# C57BL6J-background_EVX1.txt
# C57BL6J-background_EVX2.txt
# C57BL6J-background_EWSR1-FLI1.txt
# C57BL6J-background_Esrra.txt
# C57BL6J-background_Esrrg.txt
# C57BL6J-background_FEV.txt
# C57BL6J-background_FIGLA.txt
# C57BL6J-background_FLI1.txt
# C57BL6J-background_FOS.txt
# C57BL6J-background_FOS::JUN.txt
# C57BL6J-background_FOSL1.txt
# C57BL6J-background_FOSL2.txt
# C57BL6J-background_FOXA1.txt
# C57BL6J-background_FOXB1.txt
# C57BL6J-background_FOXC1.txt
# C57BL6J-background_FOXC2.txt
# C57BL6J-background_FOXD1.txt
# C57BL6J-background_FOXD2.txt
# C57BL6J-background_FOXF2.txt
# C57BL6J-background_FOXG1.txt
# C57BL6J-background_FOXH1.txt
# C57BL6J-background_FOXI1.txt
# C57BL6J-background_FOXL1.txt
# C57BL6J-background_FOXO3.txt
# C57BL6J-background_FOXO4.txt
# C57BL6J-background_FOXO6.txt
# C57BL6J-background_FOXP1.txt
# C57BL6J-background_FOXP2.txt
# C57BL6J-background_FOXP3.txt
# C57BL6J-background_Foxa2.txt
# C57BL6J-background_Foxd3.txt
# C57BL6J-background_Foxj2.txt
# C57BL6J-background_Foxj3.txt
# C57BL6J-background_Foxk1.txt
# C57BL6J-background_Foxo1.txt
# C57BL6J-background_Foxq1.txt
# reading Atf1
# C57BL6J-background_GATA1::TAL1.txt
# C57BL6J-background_GATA2.txt
# C57BL6J-background_GATA3.txt
# C57BL6J-background_GATA5.txt
# C57BL6J-background_GBX1.txt
# C57BL6J-background_GBX2.txt
# C57BL6J-background_GCM1.txt
# C57BL6J-background_GCM2.txt
# C57BL6J-background_GLI2.txt
# C57BL6J-background_GLIS1.txt
# C57BL6J-background_GLIS2.txt
# C57BL6J-background_GLIS3.txt
# C57BL6J-background_GMEB2.txt
# C57BL6J-background_GRHL1.txt
# C57BL6J-background_GSC.txt
# C57BL6J-background_GSC2.txt
# C57BL6J-background_GSX1.txt
# C57BL6J-background_GSX2.txt
# C57BL6J-background_Gabpa.txt
# C57BL6J-background_Gata1.txt
# C57BL6J-background_Gata4.txt
# C57BL6J-background_Gfi1.txt
# C57BL6J-background_Gfi1b.txt
# C57BL6J-background_Gmeb1.txt
# C57BL6J-background_HES5.txt
# C57BL6J-background_HES7.txt
# C57BL6J-background_HESX1.txt
# C57BL6J-background_HEY1.txt
# C57BL6J-background_HEY2.txt
# C57BL6J-background_HIC2.txt
# reading CUX1
# C57BL6J-background_HINFP.txt
# C57BL6J-background_HLF.txt
# reading BARHL2
# C57BL6J-background_HLTF.txtreading ALX3
#
# reading BARX1
# C57BL6J-background_HMBOX1.txt
# C57BL6J-background_HNF1A.txt
# reading BSX
# C57BL6J-background_HNF1B.txt
# readingC57BL6J-background_HNF4G.txt
# reading Barhl1
# C57BL6J-background_HOXA10.txt
#  CUX2
# C57BL6J-background_HOXA13.txt
# C57BL6J-background_HOXA2.txt
# C57BL6J-background_HOXA5.txt
# C57BL6J-background_HOXB13.txt
# reading Arid3b
# reading Arid5a
# C57BL6J-background_HOXB2.txt
# reading E2F3
# C57BL6J-background_HOXB3.txt
# reading Alx1
# reading Crem
# C57BL6J-background_HOXC10.txt
# C57BL6J-background_HOXC11.txt
# C57BL6J-background_HOXC12.txt
# C57BL6J-background_HOXC13.txt
# C57BL6J-background_HOXD11.txt
# C57BL6J-background_HOXD12.txt
# C57BL6J-background_HOXD13.txt
# C57BL6J-background_HSF1.txt
# C57BL6J-background_HSF2.txt
# C57BL6J-background_HSF4.txt
# C57BL6J-background_Hand1::Tcf3.txt
# C57BL6J-background_Hes1.txt
# C57BL6J-background_Hes2.txt
# reading DBP
# C57BL6J-background_Hic1.txt
# C57BL6J-background_Hmx1.txt
# C57BL6J-background_Hmx2.txt
# C57BL6J-background_Hmx3.txt
# C57BL6J-background_Hnf4a.txt
# reading Arx
# reading CEBPG
# C57BL6J-background_Hoxa11.txt
# C57BL6J-background_Hoxa9.txt
# reading E2F2
# C57BL6J-background_Hoxb5.txt
# reading Alx4
# C57BL6J-background_Hoxc9.txt
# C57BL6J-background_Hoxd3.txt
# reading Arnt
# C57BL6J-background_Hoxd8.txt
# C57BL6J-background_Hoxd9.txt
# reading ATF7
# reading Creb5
# C57BL6J-background_ID4.txt
# reading Arid3a
# reading Atf3
# reading DLX6
# C57BL6J-background_INSM1.txt
# C57BL6J-background_IRF1.txt
# C57BL6J-background_IRF2.txt
# C57BL6J-background_IRF7.txt
# reading CREB3
# C57BL6J-background_IRF8.txt
# reading Dlx2
# C57BL6J-background_IRF9.txt
# reading Dlx3
# reading CEBPD
# reading CDX1
# C57BL6J-background_ISL2.txt
# C57BL6J-background_ISX.txt
# C57BL6J-background_Id2.txt
# C57BL6J-background_JDP2.txt
# reading ATF4
# C57BL6J-background_JDP2_var2.txtreading Dlx1
# reading CENPB
#
# C57BL6J-background_JUN.txt
# C57BL6J-background_JUNB.txt
# reading ESX1
# reading CEBPE
# reading Dlx4
# C57BL6J-background_JUND.txt
# reading Dmbx1
# C57BL6J-background_JUND_var2.txt
# reading CEBPB
# C57BL6J-background_JUN_var2.txt
# reading DUXA
# C57BL6J-background_KLF13.txt
# C57BL6J-background_KLF14.txt
# reading EMX1
# C57BL6J-background_KLF16.txt
# C57BL6J-background_KLF5.txt
# C57BL6J-background_Klf1.txt
# C57BL6J-background_Klf12.txt
# C57BL6J-background_Klf4.txt
# C57BL6J-background_LBX1.txt
# reading EN1
# C57BL6J-background_LBX2.txt
# reading EVX2
# C57BL6J-background_LEF1.txt
# reading EVX1
# reading EMX2
# reading BHLHE22
# C57BL6J-background_LHX2.txt
# C57BL6J-background_LHX6.txt
# C57BL6J-background_LHX9.txt
# reading Dux
# C57BL6J-background_LIN54.txt
# reading E2F1
# C57BL6J-background_LMX1A.txt
# C57BL6J-background_LMX1B.txt
# reading DUX4
# C57BL6J-background_Lhx3.txt
# C57BL6J-background_Lhx4.txt
# C57BL6J-background_Lhx8.txt
# reading GMEB2
# reading BHLHE23
# C57BL6J-background_MAF::NFE2.txt
# reading BATF::JUN
# reading E2F7
# C57BL6J-background_MAFF.txt
# C57BL6J-background_MAFG.txt
# C57BL6J-background_MAFG::NFE2L1.txt
# reading Gmeb1
# C57BL6J-background_MAFK.txt
# C57BL6J-background_MAX.txt
# C57BL6J-background_MAX::MYC.txt
# C57BL6J-background_MEF2A.txt
# C57BL6J-background_MEF2B.txt
# C57BL6J-background_MEF2C.txt
# reading BHLHE41
# C57BL6J-background_MEF2D.txt
# C57BL6J-background_MEIS1.txt
# reading BHLHE40
# C57BL6J-background_MEIS2.txt
# reading CLOCK
# C57BL6J-background_MEIS3.txt
# reading BATF3
# reading BCL6B
# C57BL6J-background_MEOX1.txt
# C57BL6J-background_MEOX2.txt
# C57BL6J-background_MGA.txt
# C57BL6J-background_MIXL1.txt
# C57BL6J-background_MLX.txt
# C57BL6J-background_MLXIPL.txt
# reading DMRT3
# C57BL6J-background_MNT.txt
# reading CREB1
# C57BL6J-background_MNX1.txt
# C57BL6J-background_MSC.txt
# C57BL6J-background_MSX1.txt
# C57BL6J-background_MSX2.txt
# C57BL6J-background_MTF1.txt
# C57BL6J-background_MYBL1.txt
# C57BL6J-background_MYBL2.txt
# C57BL6J-background_MYF6.txt
# C57BL6J-background_MZF1.txt
# C57BL6J-background_MZF1_var2.txt
# C57BL6J-background_Mafb.txt
# readingC57BL6J-background_Mecom.txt
# reading Ddit3::Cebpa
# reading GATA5
# reading CREB3L1
#  CDX2
# C57BL6J-background_Mitf.txt
# C57BL6J-background_Mlxip.txt
# C57BL6J-background_Msx3.txt
# C57BL6J-background_Myb.txt
# C57BL6J-background_Myc.txt
# C57BL6J-background_Mycn.txt
# C57BL6J-background_Myod1.txt
# reading GBX1
# reading Crx
# reading Ahr::Arnt
# reading GBX2
# reading Arntl
# reading CEBPA
# reading Creb3l2
# reading ETV4
# reading GSX1
# reading Hoxa11
# reading FOXB1
# C57BL6J-background_Myog.txt
# C57BL6J-background_NEUROD2.txt
# C57BL6J-background_NEUROG2.txt
# C57BL6J-background_NFAT5.txt
# C57BL6J-background_NFATC1.txt
# C57BL6J-background_NFATC2.txt
# reading EN2
# C57BL6J-background_NFATC3.txt
# C57BL6J-background_NFE2.txt
# reading Ar
# reading GSC
# reading HOXD12
# C57BL6J-background_NFIA.txt
# reading ARNT::HIF1A
# C57BL6J-background_NFIC.txt
# reading ETV3
# C57BL6J-background_NFIC::TLX1.txt
# C57BL6J-background_NFIL3.txt
# C57BL6J-background_NFIX.txt
# C57BL6J-background_NFKB1.txt
# C57BL6J-background_NFKB2.txt
# C57BL6J-background_NFYA.txt
# C57BL6J-background_NFYB.txt
# C57BL6J-background_NHLH1.txt
# reading GSX2
# C57BL6J-background_NKX2-3.txt
# C57BL6J-background_NKX2-8.txt
# reading HOXA2
# C57BL6J-background_NKX3-2.txt
# C57BL6J-background_NKX6-1.txt
# reading HOXC11
# reading ELK1
# C57BL6J-background_NKX6-2.txt
# reading ESRRB
# C57BL6J-background_NOTO.txt
# readingreading Hmx3
# C57BL6J-background_NR1H2::RXRA.txt
#  ETV1
# C57BL6J-background_NR2C2.txt
# reading HESX1
# reading ELF1
# reading FOXP3
# reading GSC2
# C57BL6J-background_NR2F1.txt
# C57BL6J-background_NR3C1.txt
# C57BL6J-background_NR3C2.txt
# C57BL6J-background_NR4A2.txt
# C57BL6J-background_NRF1.txt
# C57BL6J-background_NRL.txt
# C57BL6J-background_Neurog1.txt
# reading FOXG1
# C57BL6J-background_Nfe2l2.txt
# reading HOXC10
# C57BL6J-background_Nkx2-5.txt
# C57BL6J-background_Nkx2-5_var2.txt
# C57BL6J-background_Nkx3-1.txt
# reading Bcl6
# C57BL6J-background_Nobox.txt
# C57BL6J-background_Npas2.txtreading FOSL2
#
# C57BL6J-background_Nr1h3::Rxra.txt
# C57BL6J-background_Nr2e1.txt
# reading FOXF2
# reading EOMES
# C57BL6J-background_Nr2e3.txt
# C57BL6J-background_Nr2f6.txt
# C57BL6J-background_Nr2f6_var2.txt
# reading HOXC12
# reading FOXH1
# reading GRHL1
# C57BL6J-background_Nr5a2.txt
# reading HOXB3
# C57BL6J-background_OLIG1.txt
# C57BL6J-background_OLIG2.txt
# reading E2F8
# C57BL6J-background_OLIG3.txt
# reading HLF
# C57BL6J-background_ONECUT1.txt
# C57BL6J-background_ONECUT2.txt
# C57BL6J-background_ONECUT3.txt
# C57BL6J-background_OTX1.txt
# C57BL6J-background_OTX2.txt
# reading FOXI1
# C57BL6J-background_PAX1.txt
# reading Foxd3
# reading FOS
# reading HNF1B
# reading HNF1A
# C57BL6J-background_PAX3.txt
# reading Atoh1
# reading ELK3
# reading Hoxd8
# reading ISX

# %%
motif_score_frame.shape
